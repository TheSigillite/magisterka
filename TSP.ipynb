# %%
import numpy as np
import pandas as pd
import networkx as nx
import traceback
import os
import matplotlib.pyplot as plt
import math
from ant_defs import Ant
import time
import tsplib95
from ant_defs import observer
from ant_defs import makestatsfile

# %%
def findbest(pop: list):
    best = Ant(0)
    best.setTourLength(100000000.0)
    for ant in pop:
        if ant.isTourViable():
            if ant < best:
                best = ant
    return best

# %% [markdown]
# ==============================================================================

# %% [markdown]
# ANT SYSTEM

# %% [markdown]
# ======================================================================================

# %%
def ASNextNodeSelection(graph: nx.DiGraph,viable_paths: list,visited: list,args: dict):
    psum = 0
    pvals = []
    for node in viable_paths:
        tmp = math.pow(graph[visited[-1]][node]["heuristic"],args['heuristic_preference']) + math.pow(graph[visited[-1]][node]["pheromone"],args['pheromone_preference'])
        pvals.append(tmp)
    s = np.sum(pvals)
    probs = [x/s for x in pvals]
    #print(probs)
    next_node = np.random.choice(a=viable_paths,p=probs,replace=False)
    #next_node = viable_paths[np.argmax(probs)]
    #print(next_node)
    #return viable_paths[np.argmax(pvals)]
    return next_node

def ASGlobalUpdate(graph: nx.DiGraph,population: list, args: dict) -> nx.DiGraph:
    for ant in population:
        #proper solutions only
        if ant.isTourViable(): 
            tour = ant.getTour()
            startnodes = tour[:-1]
            endnodes = tour[1:]
            for s,n in zip(startnodes,endnodes):
                graph[s][n]["delta"] = graph[s][n]["delta"] + (args['Qval'] / ant.getTourLength())
    evap_coef = 1-args['evaporation']
    for u, v, weight in graph.edges(data="pheromone"):
        graph[u][v]["pheromone"] = evap_coef*graph[u][v]["pheromone"] + graph[u][v]["delta"]
    nx.set_edge_attributes(graph,0.0,"delta")
    return graph

# %%
def AntSystemTSP(problem: nx.DiGraph, pop_count: int, max_cycles: int,stats_file, args: dict) -> Ant:
    start = time.time()
    best_solution_cycle = -1
    stagnation = 0
    consecutive_same_best = 0
    argslocal = args
    problem = problem
    nx.set_edge_attributes(problem,args['startpheromone'],"pheromone")
    population = []
    globalbest = Ant(1)
    globalbest.setTourLength(100000000.0)
    argslocal['globalbest'] = globalbest
    localbest = Ant(1)
    localbest.setTourLength(100000000.0)
    for i in range(0,max_cycles):
        population = []
        for k in range(0,pop_count):
            population.append(Ant(1))
        for j in range(0,len(problem)-1):
            for ant in population:
                visited = ant.getTour()
                # i forgot wtf is going on here
                # ok so we assume the last visited node is our starting node
                # and NX Graph gives us a list of all its neighbours
                # and we check if we were already there
                viable_paths = [x for x in [n for n in problem[visited[-1]]] if x not in visited]
                if len(viable_paths) == 0:
                    if j < len(problem)-1:
                        print("ant invalidated")
                        ant.invalidateTour()
                    pass
                else:
                    next_node = ASNextNodeSelection(problem,viable_paths,visited,argslocal)
                    ant.move(next_node,problem[visited[-1]][next_node]["weight"])
                #ants have moved 1 node ahead
            #most ants now have a solution ready
        for ant in population:
            visited = ant.getTour()
            ant.move(visited[0],problem[visited[-1]][visited[0]]["weight"])
        #post cycle pheromone updates and solution assesment
        #review population
        poptours = [x.getTourLength() for x in population if x.isTourViable()]
        localbest = findbest(population)
        #print(localbest.getTourLength())
        #print(consecutive_same_best)
        if localbest < globalbest:
            globalbest = localbest
            argslocal['globalbest'] = globalbest
            best_solution_cycle = i
            consecutive_same_best = 0
        else:
            consecutive_same_best = consecutive_same_best + 1
        if consecutive_same_best > 10:
            stagnation = i
            break
        problem = ASGlobalUpdate(problem,population,argslocal)
    end = time.time()
    extime = end - start
    observer(stats_file,'AS', pop_count, stagnation, best_solution_cycle,globalbest, extime, argslocal)
    return problem, globalbest

# %% [markdown]
# =====================================================================================

# %% [markdown]
# ANT COLONY ACO

# %% [markdown]
# =====================================================================================

# %%
def ACONextNodeSelection(graph: nx.DiGraph,viable_paths: list,visited: list,args: dict):
    pvals = []
    if args['selectionTypeConst'] > np.random.uniform():
        for node in viable_paths:
            tmp = graph[visited[-1]][node]["heuristic"] + math.pow(graph[visited[-1]][node]["pheromone"],args['heuristic_preference'])
            pvals.append(tmp)
        return viable_paths[np.argmax(pvals)]
    else:
        return ASNextNodeSelection(graph,viable_paths,visited,args)

def ACOGlobalPheromoneUpdate(graph: nx.DiGraph,population: list, args: dict):
    evap_coef = 1-args['evaporation']
    best = args['globalbest']
    tour = best.getTour()
    startnodes = tour[:-1]
    endnodes = tour[1:]
    for s,n in zip(startnodes,endnodes):
        graph[s][n]["delta"] += math.pow(best.getTourLength(),-1)
    for u, v, weight in graph.edges(data="pheromone"):
        graph[u][v]["pheromone"] = (evap_coef*graph[u][v]["pheromone"]) + (args['evaporation']*graph[u][v]["delta"])
    nx.set_edge_attributes(graph,0.0,"delta")
    return graph

def ACOLocalUpdateTau0(graph: nx.DiGraph, lastnode, newnode, taboo: list, args: dict):
    evap_coef = 1-args['evaporation']
    one = evap_coef*graph[lastnode][newnode]['pheromone']
    two = args['evaporation']*args['startpheromone']
    graph[lastnode][newnode]["pheromone"] = one + two
    return graph

def ACOLocalUpdateQlearning(graph: nx.DiGraph, lastnode, newnode, taboo: list, args: dict):
    evap_coef = 1-args['evaporation']
    nextnodes = [x for x in [n for n in graph[newnode]] if x not in taboo]
    if len(nextnodes) == 0:
        return ACOLocalUpdateTau0(graph,lastnode,newnode,taboo,args)
    else:
        nextphero = []
        for node in nextnodes:
            nextphero.append(graph[newnode][node]['pheromone'])
        delta = args['ACS_qlearn_gamma']*np.max(nextphero)
        one = evap_coef*graph[lastnode][newnode]['pheromone']
        two = args['evaporation']*delta
        graph[lastnode][newnode]["pheromone"] = one + two
        return graph

# %%
def ACO_TSP(problem: nx.DiGraph, pop_count: int, max_cycles: int,stats_file, args: dict) -> Ant:
    start = time.time()
    best_solution_cycle = -1
    stagnation = 0
    consecutive_same_best = 0
    argslocal = args
    problem = problem
    nx.set_edge_attributes(problem,args['startpheromone'],"pheromone")
    population = []
    globalbest = Ant(0)
    globalbest.setTourLength(100000000.0)
    argslocal['globalbest'] = globalbest
    localbest = Ant(0)
    localbest.setTourLength(100000000.0)
    for i in range(0,max_cycles):
        population = []
        for k in range(0,pop_count):
            population.append(Ant(1))
        for j in range(0,len(problem)-1):
            for ant in population:
                visited = ant.getTour()
                viable_paths = [x for x in [n for n in problem[visited[-1]]] if x not in visited]
                if len(viable_paths) == 0:
                    if j < len(problem)-1:
                        ant.invalidateTour()
                    pass
                else:
                    next_node = ACONextNodeSelection(problem,viable_paths,visited,argslocal)
                    ACOLocalUpdateQlearning(problem,visited[-1],next_node,visited,argslocal)
                    ant.move(next_node,problem[visited[-1]][next_node]["weight"])
                #ants have moved 1 node ahead
            #most ants now have a solution ready
        for ant in population:
            visited = ant.getTour()
            ant.move(visited[0],problem[visited[-1]][visited[0]]["weight"])
        #post cycle pheromone updates and solution assesment
        #review population
        localbest = findbest(population)
        if localbest < globalbest:
            globalbest = localbest
            argslocal['globalbest'] = globalbest
            best_solution_cycle = i
            consecutive_same_best = 0
        else:
            consecutive_same_best = consecutive_same_best + 1
        if consecutive_same_best > 10:
            stagnation = i
            break
        problem = ACOGlobalPheromoneUpdate(problem,population,argslocal)
    end = time.time()
    extime = end - start
    observer(stats_file,'ACO', pop_count, stagnation, best_solution_cycle,globalbest, extime, argslocal)
    return problem, globalbest

# %% [markdown]
# =====================================================================================

# %% [markdown]
# MMAS

# %% [markdown]
# =====================================================================================

# %%
def MMAStaumax(graph: nx.DiGraph, bestlength: float, args: dict):
    one = 1/(1-args['evaporation'])
    two = 1/bestlength
    max_pheromone = one * two
    args['max_pheromone'] = max_pheromone
    return args

def MMAStaumin(graph: nx.DiGraph, args: dict):
    n = graph.number_of_nodes()
    p = args['best_pheromone_selection_prob']**(1/n)
    av = n/2
    min_pheromone = (args['max_pheromone']*(1-p))/((av-1)*p)
    args['min_pheromone'] = min_pheromone
    return args

def MMASTrailSmoothing(graph: nx.DiGraph, args: dict):
    for u, v, pheromone in graph.edges(data="pheromone"):
        graph[u][v]["pheromone"] = pheromone + args['smoothing_coef']*(args['max_pheromone']-pheromone)
    return graph

def MMASGlobalUpdate(graph: nx.DiGraph,localbest, args: dict) -> nx.DiGraph:
        #proper solutions only
    tour = localbest.getTour()
    startnodes = tour[:-1]
    endnodes = tour[1:]
    for s,n in zip(startnodes,endnodes):
        graph[s][n]["delta"] += args['Qval'] / localbest.getTourLength()
    evap_coef = 1-args['evaporation']
    for u, v, weight in graph.edges(data="pheromone"):
        new_pheromone = evap_coef*graph[u][v]["pheromone"] + graph[u][v]["delta"]
        if new_pheromone > args['max_pheromone']:
            new_pheromone = args['max_pheromone']
        elif new_pheromone < args['min_pheromone']:
            new_pheromone = args['min_pheromone']
        graph[u][v]["pheromone"] = new_pheromone
    nx.set_edge_attributes(graph,0.0,"delta")
    return graph

# %%
def MMAS_TSP(problem: nx.DiGraph, pop_count: int, max_cycles: int,stats_file, args: dict) -> Ant:
    start = time.time()
    max_stagnations = 2
    current_stagnations = 0
    best_solution_cycle = -1
    stagnation = 0
    consecutive_same_best = 0
    argslocal = args
    problem = problem
    nx.set_edge_attributes(problem,args['startpheromone'],"pheromone")
    population = []
    globalbest = Ant(0)
    globalbest.setTourLength(100000000.0)
    argslocal['globalbest'] = globalbest
    localbest = Ant(0)
    localbest.setTourLength(100000000.0)
    for i in range(0,max_cycles):
        population = []
        for k in range(0,pop_count):
            population.append(Ant(1))
        for j in range(0,len(problem)-1):
            for ant in population:
                visited = ant.getTour()
                # i forgot wtf is going on here
                # ok so we assume the last visited node is our starting node
                # and NX Graph gives us a list of all its neighbours
                # and we check if we were already there
                viable_paths = [x for x in [n for n in problem[visited[-1]]] if x not in visited]
                if len(viable_paths) == 0:
                    if j < len(problem)-1:
                        ant.invalidateTour()
                    pass
                else:
                    next_node = ASNextNodeSelection(problem,viable_paths,visited,argslocal)
                    ant.move(next_node,problem[visited[-1]][next_node]["weight"])
                #ants have moved 1 node ahead
            #most ants now have a solution ready
        for ant in population:
            visited = ant.getTour()
            ant.move(visited[0],problem[visited[-1]][visited[0]]["weight"])
        #post cycle pheromone updates and solution assesment
        #review population
        localbest = findbest(population)
        if localbest < globalbest:
            globalbest = localbest
            argslocal['globalbest'] = globalbest
            best_solution_cycle = i
            consecutive_same_best = 0
        else:
            consecutive_same_best = consecutive_same_best + 1
        argslocal = MMAStaumax(problem,globalbest.getTourLength(),argslocal)
        argslocal = MMAStaumin(problem,argslocal)
        problem = MMASGlobalUpdate(problem,localbest,argslocal)
        poptours = [x.getTourLength() for x in population if x.isTourViable()]
        if consecutive_same_best > 10:
            stagnation = i
            problem = MMASTrailSmoothing(problem,argslocal)
            consecutive_same_best = 0
            current_stagnations = current_stagnations + 1
        if current_stagnations > max_stagnations:
            break
        # TODO: Find way to detect convergence and stagnation to insert trail smoothing here
    end = time.time()
    extime = end - start
    observer(stats_file,'MMAS', pop_count, stagnation, best_solution_cycle,globalbest, extime, argslocal)
    return problem, globalbest

# %% [markdown]
# =====================================================================================

# %% [markdown]
# ASRANK

# %% [markdown]
# =====================================================================================

# %%
def ASRANKGlobalUpdate(graph,population,args):
    good_solutions = [x for x in population if x.isTourViable()]
    good_solutions.sort(reverse=True)
    ranks = args['elite_multiplier']-1
    used_solutions = good_solutions[-ranks:]

    for rank, ant in enumerate(used_solutions):
        r_rank = rank + 1
        tour = ant.getTour()
        startnodes = tour[:-1]
        endnodes = tour[1:]
        for s,n in zip(startnodes,endnodes):
            graph[s][n]["delta"] += (args['Qval'] / ant.getTourLength())*r_rank
    best = args['globalbest']   
    besttour = best.getTour()
    startnodes = besttour[:-1]
    endnodes = besttour[1:]
    for s,n in zip(startnodes,endnodes):
        graph[s][n]["elite_delta"] += (args['Qval'] / best.getTourLength())*args['elite_multiplier']
    evap_coef = 1-args['evaporation']
    for u, v, weight in graph.edges(data="pheromone"):
        graph[u][v]["pheromone"] = evap_coef*graph[u][v]["pheromone"] + graph[u][v]["delta"] + graph[u][v]["elite_delta"]
    nx.set_edge_attributes(graph,0.0,"delta")
    nx.set_edge_attributes(graph,0.0,"elite_delta")
    return graph

# %%
def ASRANK_TSP(problem: nx.DiGraph, pop_count: int, max_cycles: int, stats_file, args: dict) -> Ant:
    start = time.time()
    best_solution_cycle = -1
    stagnation = 0
    consecutive_same_best = 0
    argslocal = args
    problem = problem
    nx.set_edge_attributes(problem,args['startpheromone'],"pheromone")
    nx.set_edge_attributes(problem,0.0,"elite_delta")
    population = []
    globalbest = Ant(0)
    globalbest.setTourLength(100000000.0)
    argslocal['globalbest'] = globalbest
    localbest = Ant(0)
    localbest.setTourLength(100000000.0)
    for i in range(0,max_cycles):
        population = []
        for k in range(0,pop_count):
            population.append(Ant(1))
        for j in range(0,len(problem)-1):
            for ant in population:
                visited = ant.getTour()
                # i forgot wtf is going on here
                # ok so we assume the last visited node is our starting node
                # and NX Graph gives us a list of all its neighbours
                # and we check if we were already there
                viable_paths = [x for x in [n for n in problem[visited[-1]]] if x not in visited]
                if len(viable_paths) == 0:
                    if j < len(problem)-1:
                        ant.invalidateTour()
                    pass
                else:
                    next_node = ASNextNodeSelection(problem,viable_paths,visited,argslocal)
                    ant.move(next_node,problem[visited[-1]][next_node]["weight"])
                #ants have moved 1 node ahead
            #most ants now have a solution ready
        #post cycle pheromone updates and solution assesment
        #review population
        for ant in population:
            visited = ant.getTour()
            ant.move(visited[0],problem[visited[-1]][visited[0]]["weight"])
        localbest = findbest(population)
        if localbest < globalbest:
            globalbest = localbest
            argslocal['globalbest'] = globalbest
            best_solution_cycle = i
            consecutive_same_best = 0
        else:
            consecutive_same_best = consecutive_same_best + 1
        if consecutive_same_best > 10:
            stagnation = i
            break
        problem = ASRANKGlobalUpdate(problem,population,argslocal)
    end = time.time()
    extime = end - start
    observer(stats_file,'ASRANK', pop_count, stagnation, best_solution_cycle,globalbest, extime, argslocal)
    return problem, globalbest

# %%
stats_file = makestatsfile('ftv70.csv')

# %%
p = tsplib95.load('./test_instances/ftv70.atsp')
p.edge_weights  
graph = p.get_graph()
nx.set_edge_attributes(graph,1.0,"pheromone")
nx.set_edge_attributes(graph,'b',"color")
nx.set_edge_attributes(graph,0.0,"heuristic")
nx.set_edge_attributes(graph,0.0,"delta")

for u, v, weight in graph.edges(data="weight"):
    if(weight is not None and weight != 0):
        print(f'source {u}, dest {v}, weight {weight}')
        graph[u][v]["heuristic"] = 1/weight
# Out:
# source 0, dest 0, weight 100000000
# source 0, dest 1, weight 26
# source 0, dest 2, weight 46
# source 0, dest 3, weight 74
# source 0, dest 4, weight 82
# source 0, dest 5, weight 65
# source 0, dest 6, weight 90
# source 0, dest 7, weight 104
# source 0, dest 8, weight 102
# source 0, dest 9, weight 100
# source 0, dest 10, weight 147
# source 0, dest 11, weight 134
# source 0, dest 12, weight 90
# source 0, dest 13, weight 75
# source 0, dest 14, weight 69
# source 0, dest 15, weight 106
# source 0, dest 16, weight 117
# source 0, dest 17, weight 42
# source 0, dest 18, weight 71
# source 0, dest 19, weight 96
# source 0, dest 20, weight 158
# source 0, dest 21, weight 89
# source 0, dest 22, weight 76
# source 0, dest 23, weight 125
# source 0, dest 24, weight 38
# source 0, dest 25, weight 40
# source 0, dest 26, weight 58
# source 0, dest 27, weight 59
# source 0, dest 28, weight 13
# source 0, dest 29, weight 38
# source 0, dest 30, weight 31
# source 0, dest 31, weight 22
# source 0, dest 32, weight 103
# source 0, dest 33, weight 143
# source 0, dest 34, weight 106
# source 0, dest 35, weight 94
# source 0, dest 36, weight 137
# source 0, dest 37, weight 104
# source 0, dest 38, weight 123
# source 0, dest 39, weight 140
# source 0, dest 40, weight 98
# source 0, dest 41, weight 70
# source 0, dest 42, weight 58
# source 0, dest 43, weight 38
# source 0, dest 44, weight 30
# source 0, dest 45, weight 48
# source 0, dest 46, weight 67
# source 0, dest 47, weight 118
# source 0, dest 48, weight 120
# source 0, dest 49, weight 105
# source 0, dest 50, weight 149
# source 0, dest 51, weight 140
# source 0, dest 52, weight 100
# source 0, dest 53, weight 55
# source 0, dest 54, weight 115
# source 0, dest 55, weight 141
# source 0, dest 56, weight 94
# source 0, dest 57, weight 93
# source 0, dest 58, weight 122
# source 0, dest 59, weight 113
# source 0, dest 60, weight 162
# source 0, dest 61, weight 154
# source 0, dest 62, weight 76
# source 0, dest 63, weight 118
# source 0, dest 64, weight 36
# source 0, dest 65, weight 21
# source 0, dest 66, weight 62
# source 0, dest 67, weight 165
# source 0, dest 68, weight 92
# source 0, dest 69, weight 94
# source 0, dest 70, weight 66
# source 1, dest 0, weight 66
# source 1, dest 1, weight 100000000
# source 1, dest 2, weight 20
# source 1, dest 3, weight 48
# source 1, dest 4, weight 56
# source 1, dest 5, weight 39
# source 1, dest 6, weight 126
# source 1, dest 7, weight 81
# source 1, dest 8, weight 76
# source 1, dest 9, weight 109
# source 1, dest 10, weight 156
# source 1, dest 11, weight 140
# source 1, dest 12, weight 156
# source 1, dest 13, weight 141
# source 1, dest 14, weight 135
# source 1, dest 15, weight 172
# source 1, dest 16, weight 183
# source 1, dest 17, weight 108
# source 1, dest 18, weight 137
# source 1, dest 19, weight 162
# source 1, dest 20, weight 224
# source 1, dest 21, weight 155
# source 1, dest 22, weight 142
# source 1, dest 23, weight 190
# source 1, dest 24, weight 104
# source 1, dest 25, weight 76
# source 1, dest 26, weight 124
# source 1, dest 27, weight 95
# source 1, dest 28, weight 79
# source 1, dest 29, weight 104
# source 1, dest 30, weight 97
# source 1, dest 31, weight 88
# source 1, dest 32, weight 130
# source 1, dest 33, weight 176
# source 1, dest 34, weight 133
# source 1, dest 35, weight 121
# source 1, dest 36, weight 164
# source 1, dest 37, weight 131
# source 1, dest 38, weight 150
# source 1, dest 39, weight 167
# source 1, dest 40, weight 125
# source 1, dest 41, weight 97
# source 1, dest 42, weight 85
# source 1, dest 43, weight 65
# source 1, dest 44, weight 57
# source 1, dest 45, weight 75
# source 1, dest 46, weight 94
# source 1, dest 47, weight 145
# source 1, dest 48, weight 147
# source 1, dest 49, weight 132
# source 1, dest 50, weight 160
# source 1, dest 51, weight 151
# source 1, dest 52, weight 80
# source 1, dest 53, weight 82
# source 1, dest 54, weight 142
# source 1, dest 55, weight 162
# source 1, dest 56, weight 74
# source 1, dest 57, weight 67
# source 1, dest 58, weight 96
# source 1, dest 59, weight 87
# source 1, dest 60, weight 189
# source 1, dest 61, weight 128
# source 1, dest 62, weight 103
# source 1, dest 63, weight 145
# source 1, dest 64, weight 102
# source 1, dest 65, weight 66
# source 1, dest 66, weight 128
# source 1, dest 67, weight 176
# source 1, dest 68, weight 119
# source 1, dest 69, weight 121
# source 1, dest 70, weight 40
# source 2, dest 0, weight 46
# source 2, dest 1, weight 53
# source 2, dest 2, weight 100000000
# source 2, dest 3, weight 28
# source 2, dest 4, weight 36
# source 2, dest 5, weight 19
# source 2, dest 6, weight 106
# source 2, dest 7, weight 61
# source 2, dest 8, weight 56
# source 2, dest 9, weight 89
# source 2, dest 10, weight 136
# source 2, dest 11, weight 120
# source 2, dest 12, weight 136
# source 2, dest 13, weight 121
# source 2, dest 14, weight 115
# source 2, dest 15, weight 152
# source 2, dest 16, weight 163
# source 2, dest 17, weight 88
# source 2, dest 18, weight 117
# source 2, dest 19, weight 142
# source 2, dest 20, weight 204
# source 2, dest 21, weight 135
# source 2, dest 22, weight 122
# source 2, dest 23, weight 170
# source 2, dest 24, weight 84
# source 2, dest 25, weight 56
# source 2, dest 26, weight 104
# source 2, dest 27, weight 75
# source 2, dest 28, weight 59
# source 2, dest 29, weight 84
# source 2, dest 30, weight 77
# source 2, dest 31, weight 68
# source 2, dest 32, weight 110
# source 2, dest 33, weight 156
# source 2, dest 34, weight 113
# source 2, dest 35, weight 101
# source 2, dest 36, weight 144
# source 2, dest 37, weight 111
# source 2, dest 38, weight 130
# source 2, dest 39, weight 147
# source 2, dest 40, weight 105
# source 2, dest 41, weight 77
# source 2, dest 42, weight 65
# source 2, dest 43, weight 45
# source 2, dest 44, weight 37
# source 2, dest 45, weight 55
# source 2, dest 46, weight 74
# source 2, dest 47, weight 125
# source 2, dest 48, weight 127
# source 2, dest 49, weight 112
# source 2, dest 50, weight 140
# source 2, dest 51, weight 131
# source 2, dest 52, weight 60
# source 2, dest 53, weight 62
# source 2, dest 54, weight 122
# source 2, dest 55, weight 142
# source 2, dest 56, weight 54
# source 2, dest 57, weight 47
# source 2, dest 58, weight 76
# source 2, dest 59, weight 67
# source 2, dest 60, weight 169
# source 2, dest 61, weight 108
# source 2, dest 62, weight 83
# source 2, dest 63, weight 125
# source 2, dest 64, weight 82
# source 2, dest 65, weight 46
# source 2, dest 66, weight 108
# source 2, dest 67, weight 156
# source 2, dest 68, weight 99
# source 2, dest 69, weight 101
# source 2, dest 70, weight 20
# source 3, dest 0, weight 73
# source 3, dest 1, weight 87
# source 3, dest 2, weight 72
# source 3, dest 3, weight 100000000
# source 3, dest 4, weight 30
# source 3, dest 5, weight 46
# source 3, dest 6, weight 133
# source 3, dest 7, weight 55
# source 3, dest 8, weight 50
# source 3, dest 9, weight 83
# source 3, dest 10, weight 130
# source 3, dest 11, weight 114
# source 3, dest 12, weight 158
# source 3, dest 13, weight 117
# source 3, dest 14, weight 137
# source 3, dest 15, weight 174
# source 3, dest 16, weight 185
# source 3, dest 17, weight 115
# source 3, dest 18, weight 144
# source 3, dest 19, weight 169
# source 3, dest 20, weight 231
# source 3, dest 21, weight 162
# source 3, dest 22, weight 149
# source 3, dest 23, weight 198
# source 3, dest 24, weight 111
# source 3, dest 25, weight 83
# source 3, dest 26, weight 131
# source 3, dest 27, weight 102
# source 3, dest 28, weight 86
# source 3, dest 29, weight 111
# source 3, dest 30, weight 104
# source 3, dest 31, weight 95
# source 3, dest 32, weight 176
# source 3, dest 33, weight 216
# source 3, dest 34, weight 179
# source 3, dest 35, weight 167
# source 3, dest 36, weight 210
# source 3, dest 37, weight 176
# source 3, dest 38, weight 195
# source 3, dest 39, weight 182
# source 3, dest 40, weight 140
# source 3, dest 41, weight 143
# source 3, dest 42, weight 131
# source 3, dest 43, weight 111
# source 3, dest 44, weight 103
# source 3, dest 45, weight 121
# source 3, dest 46, weight 109
# source 3, dest 47, weight 160
# source 3, dest 48, weight 162
# source 3, dest 49, weight 147
# source 3, dest 50, weight 131
# source 3, dest 51, weight 122
# source 3, dest 52, weight 94
# source 3, dest 53, weight 113
# source 3, dest 54, weight 131
# source 3, dest 55, weight 133
# source 3, dest 56, weight 56
# source 3, dest 57, weight 38
# source 3, dest 58, weight 67
# source 3, dest 59, weight 39
# source 3, dest 60, weight 235
# source 3, dest 61, weight 99
# source 3, dest 62, weight 118
# source 3, dest 63, weight 190
# source 3, dest 64, weight 109
# source 3, dest 65, weight 94
# source 3, dest 66, weight 135
# source 3, dest 67, weight 147
# source 3, dest 68, weight 162
# source 3, dest 69, weight 167
# source 3, dest 70, weight 70
# source 4, dest 0, weight 43
# source 4, dest 1, weight 57
# source 4, dest 2, weight 42
# source 4, dest 3, weight 70
# source 4, dest 4, weight 100000000
# source 4, dest 5, weight 16
# source 4, dest 6, weight 103
# source 4, dest 7, weight 25
# source 4, dest 8, weight 20
# source 4, dest 9, weight 53
# source 4, dest 10, weight 100
# source 4, dest 11, weight 84
# source 4, dest 12, weight 128
# source 4, dest 13, weight 87
# source 4, dest 14, weight 107
# source 4, dest 15, weight 144
# source 4, dest 16, weight 155
# source 4, dest 17, weight 85
# source 4, dest 18, weight 114
# source 4, dest 19, weight 139
# source 4, dest 20, weight 201
# source 4, dest 21, weight 132
# source 4, dest 22, weight 119
# source 4, dest 23, weight 168
# source 4, dest 24, weight 81
# source 4, dest 25, weight 53
# source 4, dest 26, weight 101
# source 4, dest 27, weight 72
# source 4, dest 28, weight 56
# source 4, dest 29, weight 81
# source 4, dest 30, weight 74
# source 4, dest 31, weight 65
# source 4, dest 32, weight 146
# source 4, dest 33, weight 186
# source 4, dest 34, weight 149
# source 4, dest 35, weight 137
# source 4, dest 36, weight 180
# source 4, dest 37, weight 147
# source 4, dest 38, weight 166
# source 4, dest 39, weight 183
# source 4, dest 40, weight 141
# source 4, dest 41, weight 113
# source 4, dest 42, weight 101
# source 4, dest 43, weight 81
# source 4, dest 44, weight 73
# source 4, dest 45, weight 91
# source 4, dest 46, weight 110
# source 4, dest 47, weight 161
# source 4, dest 48, weight 163
# source 4, dest 49, weight 148
# source 4, dest 50, weight 164
# source 4, dest 51, weight 155
# source 4, dest 52, weight 102
# source 4, dest 53, weight 98
# source 4, dest 54, weight 158
# source 4, dest 55, weight 166
# source 4, dest 56, weight 89
# source 4, dest 57, weight 71
# source 4, dest 58, weight 100
# source 4, dest 59, weight 42
# source 4, dest 60, weight 205
# source 4, dest 61, weight 109
# source 4, dest 62, weight 119
# source 4, dest 63, weight 161
# source 4, dest 64, weight 79
# source 4, dest 65, weight 64
# source 4, dest 66, weight 105
# source 4, dest 67, weight 180
# source 4, dest 68, weight 135
# source 4, dest 69, weight 137
# source 4, dest 70, weight 62
# source 5, dest 0, weight 27
# source 5, dest 1, weight 41
# source 5, dest 2, weight 26
# source 5, dest 3, weight 54
# source 5, dest 4, weight 62
# source 5, dest 5, weight 100000000
# source 5, dest 6, weight 87
# source 5, dest 7, weight 87
# source 5, dest 8, weight 82
# source 5, dest 9, weight 97
# source 5, dest 10, weight 144
# source 5, dest 11, weight 131
# source 5, dest 12, weight 117
# source 5, dest 13, weight 102
# source 5, dest 14, weight 96
# source 5, dest 15, weight 133
# source 5, dest 16, weight 144
# source 5, dest 17, weight 69
# source 5, dest 18, weight 98
# source 5, dest 19, weight 123
# source 5, dest 20, weight 185
# source 5, dest 21, weight 116
# source 5, dest 22, weight 103
# source 5, dest 23, weight 152
# source 5, dest 24, weight 65
# source 5, dest 25, weight 37
# source 5, dest 26, weight 85
# source 5, dest 27, weight 56
# source 5, dest 28, weight 40
# source 5, dest 29, weight 65
# source 5, dest 30, weight 58
# source 5, dest 31, weight 49
# source 5, dest 32, weight 130
# source 5, dest 33, weight 170
# source 5, dest 34, weight 133
# source 5, dest 35, weight 121
# source 5, dest 36, weight 164
# source 5, dest 37, weight 131
# source 5, dest 38, weight 150
# source 5, dest 39, weight 167
# source 5, dest 40, weight 125
# source 5, dest 41, weight 97
# source 5, dest 42, weight 85
# source 5, dest 43, weight 65
# source 5, dest 44, weight 57
# source 5, dest 45, weight 75
# source 5, dest 46, weight 94
# source 5, dest 47, weight 145
# source 5, dest 48, weight 147
# source 5, dest 49, weight 132
# source 5, dest 50, weight 166
# source 5, dest 51, weight 157
# source 5, dest 52, weight 86
# source 5, dest 53, weight 82
# source 5, dest 54, weight 142
# source 5, dest 55, weight 168
# source 5, dest 56, weight 80
# source 5, dest 57, weight 73
# source 5, dest 58, weight 102
# source 5, dest 59, weight 93
# source 5, dest 60, weight 189
# source 5, dest 61, weight 134
# source 5, dest 62, weight 103
# source 5, dest 63, weight 145
# source 5, dest 64, weight 63
# source 5, dest 65, weight 48
# source 5, dest 66, weight 89
# source 5, dest 67, weight 182
# source 5, dest 68, weight 119
# source 5, dest 69, weight 121
# source 5, dest 70, weight 46
# source 6, dest 0, weight 129
# source 6, dest 1, weight 155
# source 6, dest 2, weight 175
# source 6, dest 3, weight 203
# source 6, dest 4, weight 199
# source 6, dest 5, weight 194
# source 6, dest 6, weight 100000000
# source 6, dest 7, weight 14
# source 6, dest 8, weight 180
# source 6, dest 9, weight 38
# source 6, dest 10, weight 85
# source 6, dest 11, weight 72
# source 6, dest 12, weight 95
# source 6, dest 13, weight 54
# source 6, dest 14, weight 74
# source 6, dest 15, weight 111
# source 6, dest 16, weight 122
# source 6, dest 17, weight 87
# source 6, dest 18, weight 116
# source 6, dest 19, weight 141
# source 6, dest 20, weight 186
# source 6, dest 21, weight 134
# source 6, dest 22, weight 146
# source 6, dest 23, weight 195
# source 6, dest 24, weight 117
# source 6, dest 25, weight 117
# source 6, dest 26, weight 137
# source 6, dest 27, weight 65
# source 6, dest 28, weight 116
# source 6, dest 29, weight 148
# source 6, dest 30, weight 155
# source 6, dest 31, weight 151
# source 6, dest 32, weight 218
# source 6, dest 33, weight 213
# source 6, dest 34, weight 235
# source 6, dest 35, weight 223
# source 6, dest 36, weight 266
# source 6, dest 37, weight 233
# source 6, dest 38, weight 252
# source 6, dest 39, weight 269
# source 6, dest 40, weight 227
# source 6, dest 41, weight 199
# source 6, dest 42, weight 187
# source 6, dest 43, weight 167
# source 6, dest 44, weight 159
# source 6, dest 45, weight 177
# source 6, dest 46, weight 196
# source 6, dest 47, weight 247
# source 6, dest 48, weight 249
# source 6, dest 49, weight 234
# source 6, dest 50, weight 260
# source 6, dest 51, weight 251
# source 6, dest 52, weight 229
# source 6, dest 53, weight 184
# source 6, dest 54, weight 244
# source 6, dest 55, weight 262
# source 6, dest 56, weight 204
# source 6, dest 57, weight 186
# source 6, dest 58, weight 155
# source 6, dest 59, weight 158
# source 6, dest 60, weight 255
# source 6, dest 61, weight 157
# source 6, dest 62, weight 205
# source 6, dest 63, weight 247
# source 6, dest 64, weight 93
# source 6, dest 65, weight 150
# source 6, dest 66, weight 80
# source 6, dest 67, weight 276
# source 6, dest 68, weight 221
# source 6, dest 69, weight 223
# source 6, dest 70, weight 195
# source 7, dest 0, weight 137
# source 7, dest 1, weight 163
# source 7, dest 2, weight 183
# source 7, dest 3, weight 211
# source 7, dest 4, weight 189
# source 7, dest 5, weight 202
# source 7, dest 6, weight 104
# source 7, dest 7, weight 100000000
# source 7, dest 8, weight 170
# source 7, dest 9, weight 28
# source 7, dest 10, weight 75
# source 7, dest 11, weight 62
# source 7, dest 12, weight 103
# source 7, dest 13, weight 62
# source 7, dest 14, weight 82
# source 7, dest 15, weight 119
# source 7, dest 16, weight 130
# source 7, dest 17, weight 95
# source 7, dest 18, weight 124
# source 7, dest 19, weight 149
# source 7, dest 20, weight 194
# source 7, dest 21, weight 142
# source 7, dest 22, weight 154
# source 7, dest 23, weight 203
# source 7, dest 24, weight 125
# source 7, dest 25, weight 125
# source 7, dest 26, weight 145
# source 7, dest 27, weight 73
# source 7, dest 28, weight 124
# source 7, dest 29, weight 156
# source 7, dest 30, weight 163
# source 7, dest 31, weight 159
# source 7, dest 32, weight 226
# source 7, dest 33, weight 221
# source 7, dest 34, weight 243
# source 7, dest 35, weight 231
# source 7, dest 36, weight 274
# source 7, dest 37, weight 241
# source 7, dest 38, weight 260
# source 7, dest 39, weight 277
# source 7, dest 40, weight 235
# source 7, dest 41, weight 207
# source 7, dest 42, weight 195
# source 7, dest 43, weight 175
# source 7, dest 44, weight 167
# source 7, dest 45, weight 185
# source 7, dest 46, weight 204
# source 7, dest 47, weight 255
# source 7, dest 48, weight 257
# source 7, dest 49, weight 242
# source 7, dest 50, weight 250
# source 7, dest 51, weight 241
# source 7, dest 52, weight 232
# source 7, dest 53, weight 192
# source 7, dest 54, weight 250
# source 7, dest 55, weight 252
# source 7, dest 56, weight 194
# source 7, dest 57, weight 176
# source 7, dest 58, weight 145
# source 7, dest 59, weight 148
# source 7, dest 60, weight 263
# source 7, dest 61, weight 147
# source 7, dest 62, weight 213
# source 7, dest 63, weight 255
# source 7, dest 64, weight 101
# source 7, dest 65, weight 158
# source 7, dest 66, weight 88
# source 7, dest 67, weight 266
# source 7, dest 68, weight 229
# source 7, dest 69, weight 231
# source 7, dest 70, weight 203
# source 8, dest 0, weight 106
# source 8, dest 1, weight 120
# source 8, dest 2, weight 105
# source 8, dest 3, weight 91
# source 8, dest 4, weight 63
# source 8, dest 5, weight 79
# source 8, dest 6, weight 109
# source 8, dest 7, weight 5
# source 8, dest 8, weight 100000000
# source 8, dest 9, weight 33
# source 8, dest 10, weight 80
# source 8, dest 11, weight 64
# source 8, dest 12, weight 108
# source 8, dest 13, weight 67
# source 8, dest 14, weight 87
# source 8, dest 15, weight 124
# source 8, dest 16, weight 135
# source 8, dest 17, weight 100
# source 8, dest 18, weight 129
# source 8, dest 19, weight 154
# source 8, dest 20, weight 199
# source 8, dest 21, weight 147
# source 8, dest 22, weight 159
# source 8, dest 23, weight 208
# source 8, dest 24, weight 130
# source 8, dest 25, weight 116
# source 8, dest 26, weight 150
# source 8, dest 27, weight 78
# source 8, dest 28, weight 119
# source 8, dest 29, weight 144
# source 8, dest 30, weight 137
# source 8, dest 31, weight 128
# source 8, dest 32, weight 209
# source 8, dest 33, weight 226
# source 8, dest 34, weight 212
# source 8, dest 35, weight 200
# source 8, dest 36, weight 238
# source 8, dest 37, weight 189
# source 8, dest 38, weight 208
# source 8, dest 39, weight 195
# source 8, dest 40, weight 153
# source 8, dest 41, weight 176
# source 8, dest 42, weight 164
# source 8, dest 43, weight 144
# source 8, dest 44, weight 136
# source 8, dest 45, weight 154
# source 8, dest 46, weight 122
# source 8, dest 47, weight 173
# source 8, dest 48, weight 175
# source 8, dest 49, weight 160
# source 8, dest 50, weight 144
# source 8, dest 51, weight 135
# source 8, dest 52, weight 107
# source 8, dest 53, weight 126
# source 8, dest 54, weight 144
# source 8, dest 55, weight 146
# source 8, dest 56, weight 69
# source 8, dest 57, weight 51
# source 8, dest 58, weight 80
# source 8, dest 59, weight 22
# source 8, dest 60, weight 268
# source 8, dest 61, weight 89
# source 8, dest 62, weight 131
# source 8, dest 63, weight 203
# source 8, dest 64, weight 106
# source 8, dest 65, weight 127
# source 8, dest 66, weight 93
# source 8, dest 67, weight 160
# source 8, dest 68, weight 175
# source 8, dest 69, weight 200
# source 8, dest 70, weight 83
# source 9, dest 0, weight 109
# source 9, dest 1, weight 135
# source 9, dest 2, weight 155
# source 9, dest 3, weight 183
# source 9, dest 4, weight 161
# source 9, dest 5, weight 174
# source 9, dest 6, weight 76
# source 9, dest 7, weight 81
# source 9, dest 8, weight 142
# source 9, dest 9, weight 100000000
# source 9, dest 10, weight 47
# source 9, dest 11, weight 34
# source 9, dest 12, weight 75
# source 9, dest 13, weight 34
# source 9, dest 14, weight 54
# source 9, dest 15, weight 91
# source 9, dest 16, weight 102
# source 9, dest 17, weight 67
# source 9, dest 18, weight 96
# source 9, dest 19, weight 121
# source 9, dest 20, weight 166
# source 9, dest 21, weight 114
# source 9, dest 22, weight 126
# source 9, dest 23, weight 175
# source 9, dest 24, weight 97
# source 9, dest 25, weight 97
# source 9, dest 26, weight 117
# source 9, dest 27, weight 45
# source 9, dest 28, weight 96
# source 9, dest 29, weight 128
# source 9, dest 30, weight 135
# source 9, dest 31, weight 131
# source 9, dest 32, weight 198
# source 9, dest 33, weight 193
# source 9, dest 34, weight 215
# source 9, dest 35, weight 203
# source 9, dest 36, weight 246
# source 9, dest 37, weight 213
# source 9, dest 38, weight 232
# source 9, dest 39, weight 249
# source 9, dest 40, weight 207
# source 9, dest 41, weight 179
# source 9, dest 42, weight 167
# source 9, dest 43, weight 147
# source 9, dest 44, weight 139
# source 9, dest 45, weight 157
# source 9, dest 46, weight 176
# source 9, dest 47, weight 227
# source 9, dest 48, weight 229
# source 9, dest 49, weight 214
# source 9, dest 50, weight 222
# source 9, dest 51, weight 213
# source 9, dest 52, weight 204
# source 9, dest 53, weight 164
# source 9, dest 54, weight 222
# source 9, dest 55, weight 224
# source 9, dest 56, weight 166
# source 9, dest 57, weight 148
# source 9, dest 58, weight 117
# source 9, dest 59, weight 120
# source 9, dest 60, weight 235
# source 9, dest 61, weight 119
# source 9, dest 62, weight 185
# source 9, dest 63, weight 227
# source 9, dest 64, weight 73
# source 9, dest 65, weight 130
# source 9, dest 66, weight 60
# source 9, dest 67, weight 238
# source 9, dest 68, weight 201
# source 9, dest 69, weight 203
# source 9, dest 70, weight 175
# source 10, dest 0, weight 157
# source 10, dest 1, weight 171
# source 10, dest 2, weight 156
# source 10, dest 3, weight 141
# source 10, dest 4, weight 114
# source 10, dest 5, weight 130
# source 10, dest 6, weight 136
# source 10, dest 7, weight 34
# source 10, dest 8, weight 95
# source 10, dest 9, weight 60
# source 10, dest 10, weight 100000000
# source 10, dest 11, weight 40
# source 10, dest 12, weight 135
# source 10, dest 13, weight 94
# source 10, dest 14, weight 114
# source 10, dest 15, weight 151
# source 10, dest 16, weight 162
# source 10, dest 17, weight 127
# source 10, dest 18, weight 156
# source 10, dest 19, weight 181
# source 10, dest 20, weight 226
# source 10, dest 21, weight 174
# source 10, dest 22, weight 186
# source 10, dest 23, weight 235
# source 10, dest 24, weight 157
# source 10, dest 25, weight 157
# source 10, dest 26, weight 177
# source 10, dest 27, weight 105
# source 10, dest 28, weight 156
# source 10, dest 29, weight 188
# source 10, dest 30, weight 188
# source 10, dest 31, weight 179
# source 10, dest 32, weight 258
# source 10, dest 33, weight 253
# source 10, dest 34, weight 263
# source 10, dest 35, weight 251
# source 10, dest 36, weight 288
# source 10, dest 37, weight 239
# source 10, dest 38, weight 258
# source 10, dest 39, weight 245
# source 10, dest 40, weight 203
# source 10, dest 41, weight 227
# source 10, dest 42, weight 215
# source 10, dest 43, weight 195
# source 10, dest 44, weight 187
# source 10, dest 45, weight 205
# source 10, dest 46, weight 172
# source 10, dest 47, weight 223
# source 10, dest 48, weight 207
# source 10, dest 49, weight 210
# source 10, dest 50, weight 175
# source 10, dest 51, weight 166
# source 10, dest 52, weight 157
# source 10, dest 53, weight 176
# source 10, dest 54, weight 175
# source 10, dest 55, weight 177
# source 10, dest 56, weight 119
# source 10, dest 57, weight 101
# source 10, dest 58, weight 70
# source 10, dest 59, weight 73
# source 10, dest 60, weight 295
# source 10, dest 61, weight 72
# source 10, dest 62, weight 181
# source 10, dest 63, weight 253
# source 10, dest 64, weight 133
# source 10, dest 65, weight 178
# source 10, dest 66, weight 120
# source 10, dest 67, weight 191
# source 10, dest 68, weight 225
# source 10, dest 69, weight 251
# source 10, dest 70, weight 133
# source 11, dest 0, weight 143
# source 11, dest 1, weight 169
# source 11, dest 2, weight 174
# source 11, dest 3, weight 159
# source 11, dest 4, weight 132
# source 11, dest 5, weight 148
# source 11, dest 6, weight 110
# source 11, dest 7, weight 65
# source 11, dest 8, weight 113
# source 11, dest 9, weight 34
# source 11, dest 10, weight 31
# source 11, dest 11, weight 100000000
# source 11, dest 12, weight 102
# source 11, dest 13, weight 68
# source 11, dest 14, weight 88
# source 11, dest 15, weight 122
# source 11, dest 16, weight 133
# source 11, dest 17, weight 101
# source 11, dest 18, weight 130
# source 11, dest 19, weight 155
# source 11, dest 20, weight 197
# source 11, dest 21, weight 148
# source 11, dest 22, weight 160
# source 11, dest 23, weight 209
# source 11, dest 24, weight 131
# source 11, dest 25, weight 131
# source 11, dest 26, weight 151
# source 11, dest 27, weight 79
# source 11, dest 28, weight 130
# source 11, dest 29, weight 162
# source 11, dest 30, weight 169
# source 11, dest 31, weight 165
# source 11, dest 32, weight 232
# source 11, dest 33, weight 227
# source 11, dest 34, weight 249
# source 11, dest 35, weight 237
# source 11, dest 36, weight 280
# source 11, dest 37, weight 247
# source 11, dest 38, weight 266
# source 11, dest 39, weight 263
# source 11, dest 40, weight 221
# source 11, dest 41, weight 213
# source 11, dest 42, weight 201
# source 11, dest 43, weight 181
# source 11, dest 44, weight 173
# source 11, dest 45, weight 191
# source 11, dest 46, weight 190
# source 11, dest 47, weight 241
# source 11, dest 48, weight 225
# source 11, dest 49, weight 228
# source 11, dest 50, weight 193
# source 11, dest 51, weight 184
# source 11, dest 52, weight 175
# source 11, dest 53, weight 194
# source 11, dest 54, weight 193
# source 11, dest 55, weight 195
# source 11, dest 56, weight 137
# source 11, dest 57, weight 119
# source 11, dest 58, weight 88
# source 11, dest 59, weight 91
# source 11, dest 60, weight 269
# source 11, dest 61, weight 90
# source 11, dest 62, weight 199
# source 11, dest 63, weight 261
# source 11, dest 64, weight 107
# source 11, dest 65, weight 164
# source 11, dest 66, weight 94
# source 11, dest 67, weight 209
# source 11, dest 68, weight 235
# source 11, dest 69, weight 237
# source 11, dest 70, weight 151
# source 12, dest 0, weight 117
# source 12, dest 1, weight 143
# source 12, dest 2, weight 163
# source 12, dest 3, weight 191
# source 12, dest 4, weight 199
# source 12, dest 5, weight 182
# source 12, dest 6, weight 84
# source 12, dest 7, weight 98
# source 12, dest 8, weight 204
# source 12, dest 9, weight 73
# source 12, dest 10, weight 109
# source 12, dest 11, weight 91
# source 12, dest 12, weight 100000000
# source 12, dest 13, weight 42
# source 12, dest 14, weight 51
# source 12, dest 15, weight 44
# source 12, dest 16, weight 55
# source 12, dest 17, weight 75
# source 12, dest 18, weight 90
# source 12, dest 19, weight 96
# source 12, dest 20, weight 119
# source 12, dest 21, weight 108
# source 12, dest 22, weight 120
# source 12, dest 23, weight 165
# source 12, dest 24, weight 105
# source 12, dest 25, weight 105
# source 12, dest 26, weight 125
# source 12, dest 27, weight 53
# source 12, dest 28, weight 104
# source 12, dest 29, weight 136
# source 12, dest 30, weight 143
# source 12, dest 31, weight 139
# source 12, dest 32, weight 192
# source 12, dest 33, weight 187
# source 12, dest 34, weight 211
# source 12, dest 35, weight 204
# source 12, dest 36, weight 242
# source 12, dest 37, weight 221
# source 12, dest 38, weight 240
# source 12, dest 39, weight 257
# source 12, dest 40, weight 215
# source 12, dest 41, weight 187
# source 12, dest 42, weight 175
# source 12, dest 43, weight 155
# source 12, dest 44, weight 147
# source 12, dest 45, weight 165
# source 12, dest 46, weight 184
# source 12, dest 47, weight 235
# source 12, dest 48, weight 237
# source 12, dest 49, weight 222
# source 12, dest 50, weight 266
# source 12, dest 51, weight 257
# source 12, dest 52, weight 217
# source 12, dest 53, weight 172
# source 12, dest 54, weight 232
# source 12, dest 55, weight 258
# source 12, dest 56, weight 211
# source 12, dest 57, weight 210
# source 12, dest 58, weight 179
# source 12, dest 59, weight 182
# source 12, dest 60, weight 228
# source 12, dest 61, weight 181
# source 12, dest 62, weight 193
# source 12, dest 63, weight 235
# source 12, dest 64, weight 81
# source 12, dest 65, weight 138
# source 12, dest 66, weight 68
# source 12, dest 67, weight 282
# source 12, dest 68, weight 209
# source 12, dest 69, weight 211
# source 12, dest 70, weight 183
# source 13, dest 0, weight 75
# source 13, dest 1, weight 101
# source 13, dest 2, weight 121
# source 13, dest 3, weight 149
# source 13, dest 4, weight 157
# source 13, dest 5, weight 140
# source 13, dest 6, weight 42
# source 13, dest 7, weight 56
# source 13, dest 8, weight 176
# source 13, dest 9, weight 34
# source 13, dest 10, weight 81
# source 13, dest 11, weight 68
# source 13, dest 12, weight 41
# source 13, dest 13, weight 100000000
# source 13, dest 14, weight 20
# source 13, dest 15, weight 57
# source 13, dest 16, weight 68
# source 13, dest 17, weight 33
# source 13, dest 18, weight 62
# source 13, dest 19, weight 87
# source 13, dest 20, weight 132
# source 13, dest 21, weight 80
# source 13, dest 22, weight 92
# source 13, dest 23, weight 141
# source 13, dest 24, weight 63
# source 13, dest 25, weight 63
# source 13, dest 26, weight 83
# source 13, dest 27, weight 11
# source 13, dest 28, weight 62
# source 13, dest 29, weight 94
# source 13, dest 30, weight 101
# source 13, dest 31, weight 97
# source 13, dest 32, weight 164
# source 13, dest 33, weight 159
# source 13, dest 34, weight 181
# source 13, dest 35, weight 169
# source 13, dest 36, weight 212
# source 13, dest 37, weight 179
# source 13, dest 38, weight 198
# source 13, dest 39, weight 215
# source 13, dest 40, weight 173
# source 13, dest 41, weight 145
# source 13, dest 42, weight 133
# source 13, dest 43, weight 113
# source 13, dest 44, weight 105
# source 13, dest 45, weight 123
# source 13, dest 46, weight 142
# source 13, dest 47, weight 193
# source 13, dest 48, weight 195
# source 13, dest 49, weight 180
# source 13, dest 50, weight 224
# source 13, dest 51, weight 215
# source 13, dest 52, weight 175
# source 13, dest 53, weight 130
# source 13, dest 54, weight 190
# source 13, dest 55, weight 216
# source 13, dest 56, weight 169
# source 13, dest 57, weight 168
# source 13, dest 58, weight 151
# source 13, dest 59, weight 154
# source 13, dest 60, weight 201
# source 13, dest 61, weight 153
# source 13, dest 62, weight 151
# source 13, dest 63, weight 193
# source 13, dest 64, weight 39
# source 13, dest 65, weight 96
# source 13, dest 66, weight 26
# source 13, dest 67, weight 240
# source 13, dest 68, weight 167
# source 13, dest 69, weight 169
# source 13, dest 70, weight 141
# source 14, dest 0, weight 95
# source 14, dest 1, weight 121
# source 14, dest 2, weight 141
# source 14, dest 3, weight 169
# source 14, dest 4, weight 177
# source 14, dest 5, weight 160
# source 14, dest 6, weight 62
# source 14, dest 7, weight 76
# source 14, dest 8, weight 196
# source 14, dest 9, weight 54
# source 14, dest 10, weight 101
# source 14, dest 11, weight 88
# source 14, dest 12, weight 21
# source 14, dest 13, weight 20
# source 14, dest 14, weight 100000000
# source 14, dest 15, weight 37
# source 14, dest 16, weight 48
# source 14, dest 17, weight 53
# source 14, dest 18, weight 82
# source 14, dest 19, weight 89
# source 14, dest 20, weight 112
# source 14, dest 21, weight 100
# source 14, dest 22, weight 112
# source 14, dest 23, weight 158
# source 14, dest 24, weight 83
# source 14, dest 25, weight 83
# source 14, dest 26, weight 103
# source 14, dest 27, weight 31
# source 14, dest 28, weight 82
# source 14, dest 29, weight 114
# source 14, dest 30, weight 121
# source 14, dest 31, weight 117
# source 14, dest 32, weight 184
# source 14, dest 33, weight 179
# source 14, dest 34, weight 201
# source 14, dest 35, weight 189
# source 14, dest 36, weight 232
# source 14, dest 37, weight 199
# source 14, dest 38, weight 218
# source 14, dest 39, weight 235
# source 14, dest 40, weight 193
# source 14, dest 41, weight 165
# source 14, dest 42, weight 153
# source 14, dest 43, weight 133
# source 14, dest 44, weight 125
# source 14, dest 45, weight 143
# source 14, dest 46, weight 162
# source 14, dest 47, weight 213
# source 14, dest 48, weight 215
# source 14, dest 49, weight 200
# source 14, dest 50, weight 244
# source 14, dest 51, weight 235
# source 14, dest 52, weight 195
# source 14, dest 53, weight 150
# source 14, dest 54, weight 210
# source 14, dest 55, weight 236
# source 14, dest 56, weight 189
# source 14, dest 57, weight 188
# source 14, dest 58, weight 171
# source 14, dest 59, weight 174
# source 14, dest 60, weight 221
# source 14, dest 61, weight 173
# source 14, dest 62, weight 171
# source 14, dest 63, weight 213
# source 14, dest 64, weight 59
# source 14, dest 65, weight 116
# source 14, dest 66, weight 46
# source 14, dest 67, weight 260
# source 14, dest 68, weight 187
# source 14, dest 69, weight 189
# source 14, dest 70, weight 161
# source 15, dest 0, weight 90
# source 15, dest 1, weight 116
# source 15, dest 2, weight 136
# source 15, dest 3, weight 164
# source 15, dest 4, weight 172
# source 15, dest 5, weight 155
# source 15, dest 6, weight 99
# source 15, dest 7, weight 113
# source 15, dest 8, weight 192
# source 15, dest 9, weight 91
# source 15, dest 10, weight 138
# source 15, dest 11, weight 122
# source 15, dest 12, weight 44
# source 15, dest 13, weight 57
# source 15, dest 14, weight 37
# source 15, dest 15, weight 100000000
# source 15, dest 16, weight 11
# source 15, dest 17, weight 48
# source 15, dest 18, weight 46
# source 15, dest 19, weight 52
# source 15, dest 20, weight 75
# source 15, dest 21, weight 64
# source 15, dest 22, weight 76
# source 15, dest 23, weight 121
# source 15, dest 24, weight 78
# source 15, dest 25, weight 78
# source 15, dest 26, weight 98
# source 15, dest 27, weight 68
# source 15, dest 28, weight 77
# source 15, dest 29, weight 109
# source 15, dest 30, weight 116
# source 15, dest 31, weight 112
# source 15, dest 32, weight 148
# source 15, dest 33, weight 143
# source 15, dest 34, weight 167
# source 15, dest 35, weight 160
# source 15, dest 36, weight 198
# source 15, dest 37, weight 194
# source 15, dest 38, weight 213
# source 15, dest 39, weight 230
# source 15, dest 40, weight 188
# source 15, dest 41, weight 160
# source 15, dest 42, weight 148
# source 15, dest 43, weight 128
# source 15, dest 44, weight 120
# source 15, dest 45, weight 138
# source 15, dest 46, weight 157
# source 15, dest 47, weight 208
# source 15, dest 48, weight 210
# source 15, dest 49, weight 195
# source 15, dest 50, weight 239
# source 15, dest 51, weight 230
# source 15, dest 52, weight 190
# source 15, dest 53, weight 145
# source 15, dest 54, weight 205
# source 15, dest 55, weight 231
# source 15, dest 56, weight 184
# source 15, dest 57, weight 183
# source 15, dest 58, weight 208
# source 15, dest 59, weight 203
# source 15, dest 60, weight 184
# source 15, dest 61, weight 210
# source 15, dest 62, weight 166
# source 15, dest 63, weight 208
# source 15, dest 64, weight 54
# source 15, dest 65, weight 111
# source 15, dest 66, weight 68
# source 15, dest 67, weight 255
# source 15, dest 68, weight 182
# source 15, dest 69, weight 178
# source 15, dest 70, weight 156
# source 16, dest 0, weight 79
# source 16, dest 1, weight 105
# source 16, dest 2, weight 125
# source 16, dest 3, weight 153
# source 16, dest 4, weight 161
# source 16, dest 5, weight 144
# source 16, dest 6, weight 99
# source 16, dest 7, weight 113
# source 16, dest 8, weight 181
# source 16, dest 9, weight 91
# source 16, dest 10, weight 138
# source 16, dest 11, weight 125
# source 16, dest 12, weight 58
# source 16, dest 13, weight 57
# source 16, dest 14, weight 37
# source 16, dest 15, weight 54
# source 16, dest 16, weight 100000000
# source 16, dest 17, weight 37
# source 16, dest 18, weight 35
# source 16, dest 19, weight 41
# source 16, dest 20, weight 103
# source 16, dest 21, weight 53
# source 16, dest 22, weight 65
# source 16, dest 23, weight 114
# source 16, dest 24, weight 67
# source 16, dest 25, weight 67
# source 16, dest 26, weight 87
# source 16, dest 27, weight 68
# source 16, dest 28, weight 66
# source 16, dest 29, weight 98
# source 16, dest 30, weight 105
# source 16, dest 31, weight 101
# source 16, dest 32, weight 137
# source 16, dest 33, weight 132
# source 16, dest 34, weight 156
# source 16, dest 35, weight 149
# source 16, dest 36, weight 187
# source 16, dest 37, weight 183
# source 16, dest 38, weight 202
# source 16, dest 39, weight 219
# source 16, dest 40, weight 177
# source 16, dest 41, weight 149
# source 16, dest 42, weight 137
# source 16, dest 43, weight 117
# source 16, dest 44, weight 109
# source 16, dest 45, weight 127
# source 16, dest 46, weight 146
# source 16, dest 47, weight 197
# source 16, dest 48, weight 199
# source 16, dest 49, weight 184
# source 16, dest 50, weight 228
# source 16, dest 51, weight 219
# source 16, dest 52, weight 179
# source 16, dest 53, weight 134
# source 16, dest 54, weight 194
# source 16, dest 55, weight 220
# source 16, dest 56, weight 173
# source 16, dest 57, weight 172
# source 16, dest 58, weight 201
# source 16, dest 59, weight 192
# source 16, dest 60, weight 174
# source 16, dest 61, weight 210
# source 16, dest 62, weight 155
# source 16, dest 63, weight 197
# source 16, dest 64, weight 43
# source 16, dest 65, weight 100
# source 16, dest 66, weight 57
# source 16, dest 67, weight 244
# source 16, dest 68, weight 171
# source 16, dest 69, weight 167
# source 16, dest 70, weight 145
# source 17, dest 0, weight 42
# source 17, dest 1, weight 68
# source 17, dest 2, weight 88
# source 17, dest 3, weight 116
# source 17, dest 4, weight 124
# source 17, dest 5, weight 107
# source 17, dest 6, weight 75
# source 17, dest 7, weight 89
# source 17, dest 8, weight 144
# source 17, dest 9, weight 67
# source 17, dest 10, weight 114
# source 17, dest 11, weight 101
# source 17, dest 12, weight 48
# source 17, dest 13, weight 33
# source 17, dest 14, weight 27
# source 17, dest 15, weight 64
# source 17, dest 16, weight 75
# source 17, dest 17, weight 100000000
# source 17, dest 18, weight 29
# source 17, dest 19, weight 54
# source 17, dest 20, weight 116
# source 17, dest 21, weight 47
# source 17, dest 22, weight 59
# source 17, dest 23, weight 108
# source 17, dest 24, weight 30
# source 17, dest 25, weight 30
# source 17, dest 26, weight 50
# source 17, dest 27, weight 44
# source 17, dest 28, weight 29
# source 17, dest 29, weight 61
# source 17, dest 30, weight 68
# source 17, dest 31, weight 64
# source 17, dest 32, weight 131
# source 17, dest 33, weight 126
# source 17, dest 34, weight 148
# source 17, dest 35, weight 136
# source 17, dest 36, weight 179
# source 17, dest 37, weight 146
# source 17, dest 38, weight 165
# source 17, dest 39, weight 182
# source 17, dest 40, weight 140
# source 17, dest 41, weight 112
# source 17, dest 42, weight 100
# source 17, dest 43, weight 80
# source 17, dest 44, weight 72
# source 17, dest 45, weight 90
# source 17, dest 46, weight 109
# source 17, dest 47, weight 160
# source 17, dest 48, weight 162
# source 17, dest 49, weight 147
# source 17, dest 50, weight 191
# source 17, dest 51, weight 182
# source 17, dest 52, weight 142
# source 17, dest 53, weight 97
# source 17, dest 54, weight 157
# source 17, dest 55, weight 183
# source 17, dest 56, weight 136
# source 17, dest 57, weight 135
# source 17, dest 58, weight 164
# source 17, dest 59, weight 155
# source 17, dest 60, weight 168
# source 17, dest 61, weight 186
# source 17, dest 62, weight 118
# source 17, dest 63, weight 160
# source 17, dest 64, weight 6
# source 17, dest 65, weight 63
# source 17, dest 66, weight 20
# source 17, dest 67, weight 207
# source 17, dest 68, weight 134
# source 17, dest 69, weight 136
# source 17, dest 70, weight 108
# source 18, dest 0, weight 101
# source 18, dest 1, weight 127
# source 18, dest 2, weight 147
# source 18, dest 3, weight 175
# source 18, dest 4, weight 183
# source 18, dest 5, weight 166
# source 18, dest 6, weight 134
# source 18, dest 7, weight 148
# source 18, dest 8, weight 203
# source 18, dest 9, weight 126
# source 18, dest 10, weight 173
# source 18, dest 11, weight 160
# source 18, dest 12, weight 104
# source 18, dest 13, weight 92
# source 18, dest 14, weight 83
# source 18, dest 15, weight 69
# source 18, dest 16, weight 46
# source 18, dest 17, weight 59
# source 18, dest 18, weight 100000000
# source 18, dest 19, weight 25
# source 18, dest 20, weight 87
# source 18, dest 21, weight 18
# source 18, dest 22, weight 30
# source 18, dest 23, weight 79
# source 18, dest 24, weight 89
# source 18, dest 25, weight 89
# source 18, dest 26, weight 109
# source 18, dest 27, weight 103
# source 18, dest 28, weight 88
# source 18, dest 29, weight 120
# source 18, dest 30, weight 127
# source 18, dest 31, weight 123
# source 18, dest 32, weight 102
# source 18, dest 33, weight 97
# source 18, dest 34, weight 121
# source 18, dest 35, weight 114
# source 18, dest 36, weight 152
# source 18, dest 37, weight 162
# source 18, dest 38, weight 181
# source 18, dest 39, weight 208
# source 18, dest 40, weight 193
# source 18, dest 41, weight 144
# source 18, dest 42, weight 159
# source 18, dest 43, weight 139
# source 18, dest 44, weight 131
# source 18, dest 45, weight 149
# source 18, dest 46, weight 168
# source 18, dest 47, weight 219
# source 18, dest 48, weight 221
# source 18, dest 49, weight 206
# source 18, dest 50, weight 250
# source 18, dest 51, weight 241
# source 18, dest 52, weight 201
# source 18, dest 53, weight 156
# source 18, dest 54, weight 216
# source 18, dest 55, weight 242
# source 18, dest 56, weight 195
# source 18, dest 57, weight 194
# source 18, dest 58, weight 223
# source 18, dest 59, weight 214
# source 18, dest 60, weight 139
# source 18, dest 61, weight 245
# source 18, dest 62, weight 177
# source 18, dest 63, weight 176
# source 18, dest 64, weight 65
# source 18, dest 65, weight 122
# source 18, dest 66, weight 79
# source 18, dest 67, weight 266
# source 18, dest 68, weight 193
# source 18, dest 69, weight 132
# source 18, dest 70, weight 167
# source 19, dest 0, weight 100
# source 19, dest 1, weight 126
# source 19, dest 2, weight 146
# source 19, dest 3, weight 174
# source 19, dest 4, weight 182
# source 19, dest 5, weight 165
# source 19, dest 6, weight 120
# source 19, dest 7, weight 134
# source 19, dest 8, weight 202
# source 19, dest 9, weight 112
# source 19, dest 10, weight 159
# source 19, dest 11, weight 146
# source 19, dest 12, weight 79
# source 19, dest 13, weight 78
# source 19, dest 14, weight 58
# source 19, dest 15, weight 44
# source 19, dest 16, weight 21
# source 19, dest 17, weight 58
# source 19, dest 18, weight 56
# source 19, dest 19, weight 100000000
# source 19, dest 20, weight 62
# source 19, dest 21, weight 71
# source 19, dest 22, weight 83
# source 19, dest 23, weight 108
# source 19, dest 24, weight 88
# source 19, dest 25, weight 88
# source 19, dest 26, weight 108
# source 19, dest 27, weight 89
# source 19, dest 28, weight 87
# source 19, dest 29, weight 119
# source 19, dest 30, weight 126
# source 19, dest 31, weight 122
# source 19, dest 32, weight 155
# source 19, dest 33, weight 150
# source 19, dest 34, weight 174
# source 19, dest 35, weight 167
# source 19, dest 36, weight 205
# source 19, dest 37, weight 204
# source 19, dest 38, weight 223
# source 19, dest 39, weight 240
# source 19, dest 40, weight 198
# source 19, dest 41, weight 170
# source 19, dest 42, weight 158
# source 19, dest 43, weight 138
# source 19, dest 44, weight 130
# source 19, dest 45, weight 148
# source 19, dest 46, weight 167
# source 19, dest 47, weight 218
# source 19, dest 48, weight 220
# source 19, dest 49, weight 205
# source 19, dest 50, weight 249
# source 19, dest 51, weight 240
# source 19, dest 52, weight 200
# source 19, dest 53, weight 155
# source 19, dest 54, weight 215
# source 19, dest 55, weight 241
# source 19, dest 56, weight 194
# source 19, dest 57, weight 193
# source 19, dest 58, weight 222
# source 19, dest 59, weight 213
# source 19, dest 60, weight 171
# source 19, dest 61, weight 231
# source 19, dest 62, weight 176
# source 19, dest 63, weight 218
# source 19, dest 64, weight 64
# source 19, dest 65, weight 121
# source 19, dest 66, weight 78
# source 19, dest 67, weight 265
# source 19, dest 68, weight 192
# source 19, dest 69, weight 185
# source 19, dest 70, weight 166
# source 20, dest 0, weight 92
# source 20, dest 1, weight 118
# source 20, dest 2, weight 138
# source 20, dest 3, weight 166
# source 20, dest 4, weight 174
# source 20, dest 5, weight 157
# source 20, dest 6, weight 125
# source 20, dest 7, weight 139
# source 20, dest 8, weight 194
# source 20, dest 9, weight 117
# source 20, dest 10, weight 164
# source 20, dest 11, weight 151
# source 20, dest 12, weight 98
# source 20, dest 13, weight 83
# source 20, dest 14, weight 77
# source 20, dest 15, weight 114
# source 20, dest 16, weight 97
# source 20, dest 17, weight 50
# source 20, dest 18, weight 51
# source 20, dest 19, weight 76
# source 20, dest 20, weight 100000000
# source 20, dest 21, weight 9
# source 20, dest 22, weight 21
# source 20, dest 23, weight 46
# source 20, dest 24, weight 80
# source 20, dest 25, weight 80
# source 20, dest 26, weight 100
# source 20, dest 27, weight 94
# source 20, dest 28, weight 79
# source 20, dest 29, weight 111
# source 20, dest 30, weight 118
# source 20, dest 31, weight 114
# source 20, dest 32, weight 93
# source 20, dest 33, weight 88
# source 20, dest 34, weight 112
# source 20, dest 35, weight 105
# source 20, dest 36, weight 143
# source 20, dest 37, weight 153
# source 20, dest 38, weight 172
# source 20, dest 39, weight 199
# source 20, dest 40, weight 184
# source 20, dest 41, weight 135
# source 20, dest 42, weight 150
# source 20, dest 43, weight 130
# source 20, dest 44, weight 122
# source 20, dest 45, weight 140
# source 20, dest 46, weight 159
# source 20, dest 47, weight 210
# source 20, dest 48, weight 212
# source 20, dest 49, weight 197
# source 20, dest 50, weight 241
# source 20, dest 51, weight 232
# source 20, dest 52, weight 192
# source 20, dest 53, weight 147
# source 20, dest 54, weight 207
# source 20, dest 55, weight 233
# source 20, dest 56, weight 186
# source 20, dest 57, weight 185
# source 20, dest 58, weight 214
# source 20, dest 59, weight 205
# source 20, dest 60, weight 130
# source 20, dest 61, weight 236
# source 20, dest 62, weight 168
# source 20, dest 63, weight 167
# source 20, dest 64, weight 56
# source 20, dest 65, weight 113
# source 20, dest 66, weight 70
# source 20, dest 67, weight 257
# source 20, dest 68, weight 184
# source 20, dest 69, weight 123
# source 20, dest 70, weight 158
# source 21, dest 0, weight 83
# source 21, dest 1, weight 109
# source 21, dest 2, weight 129
# source 21, dest 3, weight 157
# source 21, dest 4, weight 165
# source 21, dest 5, weight 148
# source 21, dest 6, weight 116
# source 21, dest 7, weight 130
# source 21, dest 8, weight 185
# source 21, dest 9, weight 108
# source 21, dest 10, weight 155
# source 21, dest 11, weight 142
# source 21, dest 12, weight 89
# source 21, dest 13, weight 74
# source 21, dest 14, weight 68
# source 21, dest 15, weight 105
# source 21, dest 16, weight 88
# source 21, dest 17, weight 41
# source 21, dest 18, weight 42
# source 21, dest 19, weight 67
# source 21, dest 20, weight 129
# source 21, dest 21, weight 100000000
# source 21, dest 22, weight 12
# source 21, dest 23, weight 61
# source 21, dest 24, weight 71
# source 21, dest 25, weight 71
# source 21, dest 26, weight 91
# source 21, dest 27, weight 85
# source 21, dest 28, weight 70
# source 21, dest 29, weight 102
# source 21, dest 30, weight 109
# source 21, dest 31, weight 105
# source 21, dest 32, weight 84
# source 21, dest 33, weight 79
# source 21, dest 34, weight 103
# source 21, dest 35, weight 96
# source 21, dest 36, weight 134
# source 21, dest 37, weight 144
# source 21, dest 38, weight 163
# source 21, dest 39, weight 190
# source 21, dest 40, weight 175
# source 21, dest 41, weight 126
# source 21, dest 42, weight 141
# source 21, dest 43, weight 121
# source 21, dest 44, weight 113
# source 21, dest 45, weight 131
# source 21, dest 46, weight 150
# source 21, dest 47, weight 201
# source 21, dest 48, weight 203
# source 21, dest 49, weight 188
# source 21, dest 50, weight 232
# source 21, dest 51, weight 223
# source 21, dest 52, weight 183
# source 21, dest 53, weight 138
# source 21, dest 54, weight 198
# source 21, dest 55, weight 224
# source 21, dest 56, weight 177
# source 21, dest 57, weight 176
# source 21, dest 58, weight 205
# source 21, dest 59, weight 196
# source 21, dest 60, weight 121
# source 21, dest 61, weight 227
# source 21, dest 62, weight 159
# source 21, dest 63, weight 158
# source 21, dest 64, weight 47
# source 21, dest 65, weight 104
# source 21, dest 66, weight 61
# source 21, dest 67, weight 248
# source 21, dest 68, weight 175
# source 21, dest 69, weight 114
# source 21, dest 70, weight 149
# source 22, dest 0, weight 71
# source 22, dest 1, weight 97
# source 22, dest 2, weight 117
# source 22, dest 3, weight 145
# source 22, dest 4, weight 153
# source 22, dest 5, weight 136
# source 22, dest 6, weight 104
# source 22, dest 7, weight 118
# source 22, dest 8, weight 173
# source 22, dest 9, weight 96
# source 22, dest 10, weight 143
# source 22, dest 11, weight 130
# source 22, dest 12, weight 77
# source 22, dest 13, weight 62
# source 22, dest 14, weight 56
# source 22, dest 15, weight 93
# source 22, dest 16, weight 76
# source 22, dest 17, weight 29
# source 22, dest 18, weight 30
# source 22, dest 19, weight 55
# source 22, dest 20, weight 117
# source 22, dest 21, weight 48
# source 22, dest 22, weight 100000000
# source 22, dest 23, weight 49
# source 22, dest 24, weight 59
# source 22, dest 25, weight 59
# source 22, dest 26, weight 79
# ...
# source 63, dest 45, weight 153
# source 63, dest 46, weight 53
# source 63, dest 47, weight 90
# source 63, dest 48, weight 106
# source 63, dest 49, weight 91
# source 63, dest 50, weight 135
# source 63, dest 51, weight 126
# source 63, dest 52, weight 99
# source 63, dest 53, weight 118
# source 63, dest 54, weight 101
# source 63, dest 55, weight 127
# source 63, dest 56, weight 142
# source 63, dest 57, weight 174
# source 63, dest 58, weight 203
# source 63, dest 59, weight 194
# source 63, dest 60, weight 115
# source 63, dest 61, weight 235
# source 63, dest 62, weight 62
# source 63, dest 63, weight 100000000
# source 63, dest 64, weight 168
# source 63, dest 65, weight 144
# source 63, dest 66, weight 182
# source 63, dest 67, weight 151
# source 63, dest 68, weight 39
# source 63, dest 69, weight 87
# source 63, dest 70, weight 147
# source 64, dest 0, weight 36
# source 64, dest 1, weight 62
# source 64, dest 2, weight 82
# source 64, dest 3, weight 110
# source 64, dest 4, weight 118
# source 64, dest 5, weight 101
# source 64, dest 6, weight 74
# source 64, dest 7, weight 88
# source 64, dest 8, weight 138
# source 64, dest 9, weight 73
# source 64, dest 10, weight 120
# source 64, dest 11, weight 107
# source 64, dest 12, weight 54
# source 64, dest 13, weight 39
# source 64, dest 14, weight 33
# source 64, dest 15, weight 70
# source 64, dest 16, weight 81
# source 64, dest 17, weight 6
# source 64, dest 18, weight 35
# source 64, dest 19, weight 60
# source 64, dest 20, weight 122
# source 64, dest 21, weight 53
# source 64, dest 22, weight 62
# source 64, dest 23, weight 111
# source 64, dest 24, weight 24
# source 64, dest 25, weight 24
# source 64, dest 26, weight 44
# source 64, dest 27, weight 43
# source 64, dest 28, weight 23
# source 64, dest 29, weight 55
# source 64, dest 30, weight 62
# source 64, dest 31, weight 58
# source 64, dest 32, weight 134
# source 64, dest 33, weight 129
# source 64, dest 34, weight 142
# source 64, dest 35, weight 130
# source 64, dest 36, weight 173
# source 64, dest 37, weight 140
# source 64, dest 38, weight 159
# source 64, dest 39, weight 176
# source 64, dest 40, weight 134
# source 64, dest 41, weight 106
# source 64, dest 42, weight 94
# source 64, dest 43, weight 74
# source 64, dest 44, weight 66
# source 64, dest 45, weight 84
# source 64, dest 46, weight 103
# source 64, dest 47, weight 154
# source 64, dest 48, weight 156
# source 64, dest 49, weight 141
# source 64, dest 50, weight 185
# source 64, dest 51, weight 176
# source 64, dest 52, weight 136
# source 64, dest 53, weight 91
# source 64, dest 54, weight 151
# source 64, dest 55, weight 177
# source 64, dest 56, weight 130
# source 64, dest 57, weight 129
# source 64, dest 58, weight 158
# source 64, dest 59, weight 149
# source 64, dest 60, weight 171
# source 64, dest 61, weight 190
# source 64, dest 62, weight 112
# source 64, dest 63, weight 154
# source 64, dest 64, weight 100000000
# source 64, dest 65, weight 57
# source 64, dest 66, weight 26
# source 64, dest 67, weight 201
# source 64, dest 68, weight 128
# source 64, dest 69, weight 130
# source 64, dest 70, weight 102
# source 65, dest 0, weight 21
# source 65, dest 1, weight 7
# source 65, dest 2, weight 27
# source 65, dest 3, weight 55
# source 65, dest 4, weight 63
# source 65, dest 5, weight 46
# source 65, dest 6, weight 111
# source 65, dest 7, weight 88
# source 65, dest 8, weight 83
# source 65, dest 9, weight 116
# source 65, dest 10, weight 163
# source 65, dest 11, weight 147
# source 65, dest 12, weight 111
# source 65, dest 13, weight 96
# source 65, dest 14, weight 90
# source 65, dest 15, weight 127
# source 65, dest 16, weight 138
# source 65, dest 17, weight 63
# source 65, dest 18, weight 92
# source 65, dest 19, weight 117
# source 65, dest 20, weight 179
# source 65, dest 21, weight 110
# source 65, dest 22, weight 97
# source 65, dest 23, weight 142
# source 65, dest 24, weight 59
# source 65, dest 25, weight 61
# source 65, dest 26, weight 79
# source 65, dest 27, weight 80
# source 65, dest 28, weight 34
# source 65, dest 29, weight 41
# source 65, dest 30, weight 34
# source 65, dest 31, weight 25
# source 65, dest 32, weight 82
# source 65, dest 33, weight 128
# source 65, dest 34, weight 85
# source 65, dest 35, weight 73
# source 65, dest 36, weight 116
# source 65, dest 37, weight 83
# source 65, dest 38, weight 102
# source 65, dest 39, weight 119
# source 65, dest 40, weight 77
# source 65, dest 41, weight 49
# source 65, dest 42, weight 37
# source 65, dest 43, weight 17
# source 65, dest 44, weight 9
# source 65, dest 45, weight 27
# source 65, dest 46, weight 46
# source 65, dest 47, weight 97
# source 65, dest 48, weight 99
# source 65, dest 49, weight 84
# source 65, dest 50, weight 128
# source 65, dest 51, weight 119
# source 65, dest 52, weight 79
# source 65, dest 53, weight 34
# source 65, dest 54, weight 94
# source 65, dest 55, weight 120
# source 65, dest 56, weight 73
# source 65, dest 57, weight 74
# source 65, dest 58, weight 103
# source 65, dest 59, weight 94
# source 65, dest 60, weight 141
# source 65, dest 61, weight 135
# source 65, dest 62, weight 55
# source 65, dest 63, weight 97
# source 65, dest 64, weight 57
# source 65, dest 65, weight 100000000
# source 65, dest 66, weight 83
# source 65, dest 67, weight 144
# source 65, dest 68, weight 71
# source 65, dest 69, weight 73
# source 65, dest 70, weight 47
# source 66, dest 0, weight 102
# source 66, dest 1, weight 128
# source 66, dest 2, weight 148
# source 66, dest 3, weight 176
# source 66, dest 4, weight 184
# source 66, dest 5, weight 167
# source 66, dest 6, weight 69
# source 66, dest 7, weight 83
# source 66, dest 8, weight 203
# source 66, dest 9, weight 61
# source 66, dest 10, weight 108
# source 66, dest 11, weight 95
# source 66, dest 12, weight 28
# source 66, dest 13, weight 27
# source 66, dest 14, weight 7
# source 66, dest 15, weight 44
# source 66, dest 16, weight 55
# source 66, dest 17, weight 60
# source 66, dest 18, weight 89
# source 66, dest 19, weight 96
# source 66, dest 20, weight 119
# source 66, dest 21, weight 107
# source 66, dest 22, weight 119
# source 66, dest 23, weight 165
# source 66, dest 24, weight 90
# source 66, dest 25, weight 90
# source 66, dest 26, weight 110
# source 66, dest 27, weight 38
# source 66, dest 28, weight 89
# source 66, dest 29, weight 121
# source 66, dest 30, weight 128
# source 66, dest 31, weight 124
# source 66, dest 32, weight 191
# source 66, dest 33, weight 186
# source 66, dest 34, weight 208
# source 66, dest 35, weight 196
# source 66, dest 36, weight 239
# source 66, dest 37, weight 206
# source 66, dest 38, weight 225
# source 66, dest 39, weight 242
# source 66, dest 40, weight 200
# source 66, dest 41, weight 172
# source 66, dest 42, weight 160
# source 66, dest 43, weight 140
# source 66, dest 44, weight 132
# source 66, dest 45, weight 150
# source 66, dest 46, weight 169
# source 66, dest 47, weight 220
# source 66, dest 48, weight 222
# source 66, dest 49, weight 207
# source 66, dest 50, weight 251
# source 66, dest 51, weight 242
# source 66, dest 52, weight 202
# source 66, dest 53, weight 157
# source 66, dest 54, weight 217
# source 66, dest 55, weight 243
# source 66, dest 56, weight 196
# source 66, dest 57, weight 195
# source 66, dest 58, weight 178
# source 66, dest 59, weight 181
# source 66, dest 60, weight 228
# source 66, dest 61, weight 180
# source 66, dest 62, weight 178
# source 66, dest 63, weight 220
# source 66, dest 64, weight 66
# source 66, dest 65, weight 123
# source 66, dest 66, weight 100000000
# source 66, dest 67, weight 267
# source 66, dest 68, weight 194
# source 66, dest 69, weight 196
# source 66, dest 70, weight 168
# source 67, dest 0, weight 164
# source 67, dest 1, weight 150
# source 67, dest 2, weight 170
# source 67, dest 3, weight 154
# source 67, dest 4, weight 184
# source 67, dest 5, weight 189
# source 67, dest 6, weight 254
# source 67, dest 7, weight 209
# source 67, dest 8, weight 204
# source 67, dest 9, weight 237
# source 67, dest 10, weight 276
# source 67, dest 11, weight 245
# source 67, dest 12, weight 254
# source 67, dest 13, weight 239
# source 67, dest 14, weight 233
# source 67, dest 15, weight 270
# source 67, dest 16, weight 281
# source 67, dest 17, weight 206
# source 67, dest 18, weight 235
# source 67, dest 19, weight 260
# source 67, dest 20, weight 322
# source 67, dest 21, weight 253
# source 67, dest 22, weight 217
# source 67, dest 23, weight 240
# source 67, dest 24, weight 202
# source 67, dest 25, weight 204
# source 67, dest 26, weight 199
# source 67, dest 27, weight 223
# source 67, dest 28, weight 177
# source 67, dest 29, weight 184
# source 67, dest 30, weight 177
# source 67, dest 31, weight 168
# source 67, dest 32, weight 180
# source 67, dest 33, weight 215
# source 67, dest 34, weight 173
# source 67, dest 35, weight 171
# source 67, dest 36, weight 152
# source 67, dest 37, weight 137
# source 67, dest 38, weight 122
# source 67, dest 39, weight 65
# source 67, dest 40, weight 101
# source 67, dest 41, weight 147
# source 67, dest 42, weight 135
# source 67, dest 43, weight 142
# source 67, dest 44, weight 134
# source 67, dest 45, weight 152
# source 67, dest 46, weight 113
# source 67, dest 47, weight 43
# source 67, dest 48, weight 41
# source 67, dest 49, weight 26
# source 67, dest 50, weight 70
# source 67, dest 51, weight 61
# source 67, dest 52, weight 98
# source 67, dest 53, weight 117
# source 67, dest 54, weight 100
# source 67, dest 55, weight 112
# source 67, dest 56, weight 141
# source 67, dest 57, weight 167
# source 67, dest 58, weight 157
# source 67, dest 59, weight 193
# source 67, dest 60, weight 198
# source 67, dest 61, weight 189
# source 67, dest 62, weight 122
# source 67, dest 63, weight 151
# source 67, dest 64, weight 200
# source 67, dest 65, weight 143
# source 67, dest 66, weight 226
# source 67, dest 67, weight 100000000
# source 67, dest 68, weight 123
# source 67, dest 69, weight 171
# source 67, dest 70, weight 146
# source 68, dest 0, weight 126
# source 68, dest 1, weight 112
# source 68, dest 2, weight 132
# source 68, dest 3, weight 116
# source 68, dest 4, weight 146
# source 68, dest 5, weight 151
# source 68, dest 6, weight 216
# source 68, dest 7, weight 171
# source 68, dest 8, weight 166
# source 68, dest 9, weight 199
# source 68, dest 10, weight 246
# source 68, dest 11, weight 230
# source 68, dest 12, weight 216
# source 68, dest 13, weight 201
# source 68, dest 14, weight 195
# source 68, dest 15, weight 232
# source 68, dest 16, weight 237
# source 68, dest 17, weight 168
# source 68, dest 18, weight 191
# source 68, dest 19, weight 216
# source 68, dest 20, weight 278
# source 68, dest 21, weight 209
# source 68, dest 22, weight 161
# source 68, dest 23, weight 184
# source 68, dest 24, weight 164
# source 68, dest 25, weight 166
# source 68, dest 26, weight 143
# source 68, dest 27, weight 185
# source 68, dest 28, weight 139
# source 68, dest 29, weight 146
# source 68, dest 30, weight 139
# source 68, dest 31, weight 130
# source 68, dest 32, weight 124
# source 68, dest 33, weight 170
# source 68, dest 34, weight 127
# source 68, dest 35, weight 115
# source 68, dest 36, weight 130
# source 68, dest 37, weight 81
# source 68, dest 38, weight 100
# source 68, dest 39, weight 87
# source 68, dest 40, weight 45
# source 68, dest 41, weight 91
# source 68, dest 42, weight 79
# source 68, dest 43, weight 92
# source 68, dest 44, weight 96
# source 68, dest 45, weight 114
# source 68, dest 46, weight 14
# source 68, dest 47, weight 65
# source 68, dest 48, weight 67
# source 68, dest 49, weight 52
# source 68, dest 50, weight 96
# source 68, dest 51, weight 87
# source 68, dest 52, weight 60
# source 68, dest 53, weight 79
# source 68, dest 54, weight 62
# source 68, dest 55, weight 88
# source 68, dest 56, weight 103
# source 68, dest 57, weight 135
# source 68, dest 58, weight 164
# source 68, dest 59, weight 155
# source 68, dest 60, weight 176
# source 68, dest 61, weight 196
# source 68, dest 62, weight 23
# source 68, dest 63, weight 95
# source 68, dest 64, weight 162
# source 68, dest 65, weight 105
# source 68, dest 66, weight 188
# source 68, dest 67, weight 112
# source 68, dest 68, weight 100000000
# source 68, dest 69, weight 115
# source 68, dest 70, weight 108
# source 69, dest 0, weight 225
# source 69, dest 1, weight 211
# source 69, dest 2, weight 231
# source 69, dest 3, weight 215
# source 69, dest 4, weight 245
# source 69, dest 5, weight 250
# source 69, dest 6, weight 297
# source 69, dest 7, weight 270
# source 69, dest 8, weight 265
# source 69, dest 9, weight 289
# source 69, dest 10, weight 336
# source 69, dest 11, weight 323
# source 69, dest 12, weight 270
# source 69, dest 13, weight 255
# source 69, dest 14, weight 249
# source 69, dest 15, weight 286
# source 69, dest 16, weight 269
# source 69, dest 17, weight 222
# source 69, dest 18, weight 223
# source 69, dest 19, weight 248
# source 69, dest 20, weight 306
# source 69, dest 21, weight 241
# source 69, dest 22, weight 193
# source 69, dest 23, weight 211
# source 69, dest 24, weight 252
# source 69, dest 25, weight 252
# source 69, dest 26, weight 175
# source 69, dest 27, weight 266
# source 69, dest 28, weight 238
# source 69, dest 29, weight 245
# source 69, dest 30, weight 238
# source 69, dest 31, weight 229
# source 69, dest 32, weight 156
# source 69, dest 33, weight 158
# source 69, dest 34, weight 116
# source 69, dest 35, weight 128
# source 69, dest 36, weight 95
# source 69, dest 37, weight 46
# source 69, dest 38, weight 65
# source 69, dest 39, weight 92
# source 69, dest 40, weight 77
# source 69, dest 41, weight 12
# source 69, dest 42, weight 111
# source 69, dest 43, weight 124
# source 69, dest 44, weight 195
# source 69, dest 45, weight 213
# source 69, dest 46, weight 113
# source 69, dest 47, weight 129
# source 69, dest 48, weight 151
# source 69, dest 49, weight 151
# source 69, dest 50, weight 195
# source 69, dest 51, weight 186
# source 69, dest 52, weight 159
# source 69, dest 53, weight 178
# source 69, dest 54, weight 161
# source 69, dest 55, weight 187
# source 69, dest 56, weight 202
# source 69, dest 57, weight 234
# source 69, dest 58, weight 263
# source 69, dest 59, weight 254
# source 69, dest 60, weight 141
# source 69, dest 61, weight 295
# source 69, dest 62, weight 122
# source 69, dest 63, weight 60
# source 69, dest 64, weight 228
# source 69, dest 65, weight 204
# source 69, dest 66, weight 242
# source 69, dest 67, weight 211
# source 69, dest 68, weight 99
# source 69, dest 69, weight 100000000
# source 69, dest 70, weight 207
# source 70, dest 0, weight 81
# source 70, dest 1, weight 95
# source 70, dest 2, weight 80
# source 70, dest 3, weight 8
# source 70, dest 4, weight 38
# source 70, dest 5, weight 54
# source 70, dest 6, weight 141
# source 70, dest 7, weight 63
# source 70, dest 8, weight 58
# source 70, dest 9, weight 91
# source 70, dest 10, weight 138
# source 70, dest 11, weight 122
# source 70, dest 12, weight 166
# source 70, dest 13, weight 125
# source 70, dest 14, weight 145
# source 70, dest 15, weight 182
# source 70, dest 16, weight 193
# source 70, dest 17, weight 123
# source 70, dest 18, weight 152
# source 70, dest 19, weight 177
# source 70, dest 20, weight 239
# source 70, dest 21, weight 170
# source 70, dest 22, weight 157
# source 70, dest 23, weight 206
# source 70, dest 24, weight 119
# source 70, dest 25, weight 91
# source 70, dest 26, weight 139
# source 70, dest 27, weight 110
# source 70, dest 28, weight 94
# source 70, dest 29, weight 119
# source 70, dest 30, weight 112
# source 70, dest 31, weight 103
# source 70, dest 32, weight 184
# source 70, dest 33, weight 224
# source 70, dest 34, weight 187
# source 70, dest 35, weight 175
# source 70, dest 36, weight 214
# source 70, dest 37, weight 165
# source 70, dest 38, weight 184
# source 70, dest 39, weight 171
# source 70, dest 40, weight 129
# source 70, dest 41, weight 151
# source 70, dest 42, weight 139
# source 70, dest 43, weight 119
# source 70, dest 44, weight 111
# source 70, dest 45, weight 129
# source 70, dest 46, weight 98
# source 70, dest 47, weight 149
# source 70, dest 48, weight 151
# source 70, dest 49, weight 136
# source 70, dest 50, weight 120
# source 70, dest 51, weight 111
# source 70, dest 52, weight 83
# source 70, dest 53, weight 102
# source 70, dest 54, weight 120
# source 70, dest 55, weight 122
# source 70, dest 56, weight 45
# source 70, dest 57, weight 27
# source 70, dest 58, weight 56
# source 70, dest 59, weight 47
# source 70, dest 60, weight 243
# source 70, dest 61, weight 88
# source 70, dest 62, weight 107
# source 70, dest 63, weight 179
# source 70, dest 64, weight 117
# source 70, dest 65, weight 102
# source 70, dest 66, weight 143
# source 70, dest 67, weight 136
# source 70, dest 68, weight 151
# source 70, dest 69, weight 175

# %%
# from QAPInstances import getBur26a
# burA, burB = getBur26a()
# burA = np.matrix(burA)
# burB = np.matrix(burB)
# vectA = burA.sum(axis=1)
# vectB = burB.sum(axis=1)
# graphweights = np.dot(vectA,vectB.T)
# graph = nx.from_numpy_matrix(graphweights, create_using=nx.DiGraph)
# nx.set_edge_attributes(graph,1.0,"pheromone")
# nx.set_edge_attributes(graph,'b',"color")
# nx.set_edge_attributes(graph,0.0,"heuristic")
# nx.set_edge_attributes(graph,0.0,"delta")

# for u, v, weight in graph.edges(data="weight"):
#     if(weight is not None and weight != 0):
#         print(f'source {u}, dest {v}, weight {weight}')
#         graph[u][v]["heuristic"] = 1/weight

# %%
args_AS = {
    'pheromone_preference': 10,
    'heuristic_preference': 10,
    'Qval': 1,
    'evaporation': 0.9,
    'startpheromone': 2.0
}

args_ACO = {
    'pheromone_preference': 10,
    'heuristic_preference': 10,
    'Qval': 1,
    'evaporation': 0.9,
    'startpheromone': 2.0,
    'selectionTypeConst': 0.3,
    'ACS_qlearn_gamma': 0.5
}

args_MMAS = {
    'pheromone_preference': 10,
    'heuristic_preference': 10,
    'Qval': 1,
    'evaporation': 0.9,
    'startpheromone': 2.0,
    'best_pheromone_selection_prob': 0.05,
    'max_pheromone': 4.0,
    'min_pheromone': 0.5,
    'smoothing_coef': 0.5
}

args_ASRANK = {
    'pheromone_preference': 10,
    'heuristic_preference': 5,
    'Qval': 1,
    'evaporation': 0.9,
    'startpheromone': 1.0,
    'elite_multiplier': 35
}

# args_AS = {
#     'pheromone_preference': 1,
#     'heuristic_preference': 1,
#     'Qval': 1,
#     'evaporation': 0.5,
#     'startpheromone': 1.0
# }

# args_ACO = {
#     'pheromone_preference': 1,
#     'heuristic_preference': 1,
#     'Qval': 1,
#     'evaporation': 0.5,
#     'startpheromone': 1.0,
#     'selectionTypeConst': 0.5,
#     'ACS_qlearn_gamma': 0.5
# }

# args_MMAS = {
#     'pheromone_preference': 1,
#     'heuristic_preference': 1,
#     'Qval': 1,
#     'evaporation': 0.5,
#     'startpheromone': 1.0,
#     'best_pheromone_selection_prob': 0.05,
#     'max_pheromone': 2.0,
#     'min_pheromone': 0.5,
#     'smoothing_coef': 0.5
# }

# args_ASRANK = {
#     'pheromone_preference': 1,
#     'heuristic_preference': 1,
#     'Qval': 1,
#     'evaporation': 0.5,
#     'startpheromone': 1.0,
#     'elite_multiplier': 62
# }
# kro124p - 36230
# ft53 - 6905
# ft70 - 1950
# ftv35 - 1473

# %%
for d in range(0,5):
    G, solution = AntSystemTSP(graph,70,1000,stats_file,args_AS)
    besttour = solution.getTour()
    print(besttour)
    print(solution.getTourLength())
# Out:
# [1, 2, 70, 3, 4, 5, 0, 28, 25, 27, 6, 7, 9, 11, 10, 58, 61, 59, 8, 57, 56, 52, 46, 62, 49, 48, 51, 50, 67, 47, 39, 40, 68, 54, 55, 53, 44, 43, 42, 41, 37, 63, 38, 36, 34, 35, 69, 60, 33, 32, 26, 22, 64, 17, 66, 14, 13, 12, 15, 16, 18, 21, 23, 19, 20, 24, 29, 30, 31, 65, 45, 1]
# 2206.0
# [1, 2, 5, 0, 28, 64, 17, 66, 14, 12, 13, 27, 6, 7, 9, 11, 10, 58, 61, 59, 8, 57, 56, 70, 3, 4, 25, 15, 16, 18, 21, 22, 23, 60, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 38, 36, 43, 42, 32, 26, 19, 20, 24, 29, 30, 31, 65, 44, 45, 53, 52, 54, 55, 1]
# 2267.0
# [1, 2, 5, 25, 27, 6, 7, 9, 11, 10, 58, 61, 59, 8, 57, 56, 70, 3, 4, 0, 28, 64, 17, 66, 14, 13, 12, 15, 16, 18, 21, 22, 23, 60, 33, 35, 34, 69, 41, 37, 38, 36, 63, 40, 68, 46, 62, 49, 47, 39, 48, 51, 50, 67, 54, 55, 52, 53, 44, 65, 43, 42, 32, 26, 19, 20, 24, 29, 30, 31, 45, 1]
# 2121.0
# [1, 2, 5, 0, 28, 25, 27, 6, 7, 9, 11, 10, 58, 61, 59, 8, 57, 56, 70, 3, 4, 31, 30, 29, 24, 26, 22, 17, 64, 66, 14, 13, 12, 15, 16, 18, 21, 19, 20, 23, 60, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 38, 36, 42, 32, 65, 44, 43, 54, 55, 52, 53, 45, 1]
# 2257.0
# [1, 2, 5, 0, 28, 64, 17, 66, 14, 13, 27, 6, 7, 9, 11, 10, 58, 61, 59, 8, 57, 56, 70, 3, 4, 25, 12, 15, 16, 18, 19, 20, 21, 22, 23, 60, 33, 32, 26, 24, 29, 30, 31, 65, 44, 43, 42, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 38, 36, 34, 35, 69, 54, 55, 52, 53, 45, 1]
# 2207.0

# %%
for d in range(0,5):
    graph, solution = ACO_TSP(graph,70,1000,stats_file,args_ACO)
    besttour = solution.getTour()
    print(besttour)
    print(solution.getTourLength())
# Out:
# [1, 2, 5, 25, 27, 6, 7, 9, 11, 10, 58, 61, 57, 56, 70, 3, 4, 8, 59, 0, 28, 24, 26, 22, 18, 21, 17, 64, 66, 14, 12, 13, 15, 16, 19, 20, 23, 60, 33, 32, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 38, 36, 42, 43, 54, 55, 52, 53, 44, 65, 45, 29, 30, 31, 1]
# 2234.0
# [1, 2, 5, 0, 28, 24, 26, 22, 18, 21, 17, 64, 25, 27, 6, 7, 9, 11, 10, 59, 8, 13, 66, 14, 12, 15, 16, 19, 20, 23, 60, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 54, 55, 56, 70, 3, 57, 58, 61, 4, 65, 44, 43, 42, 32, 36, 38, 39, 47, 48, 51, 50, 67, 49, 52, 53, 45, 31, 30, 29, 1]
# 2209.0
# [1, 2, 5, 0, 28, 24, 26, 22, 18, 21, 17, 64, 25, 27, 6, 7, 9, 11, 10, 58, 61, 57, 56, 70, 3, 59, 8, 13, 66, 14, 12, 15, 16, 19, 20, 23, 60, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 52, 53, 44, 43, 42, 32, 36, 38, 39, 47, 48, 51, 50, 67, 49, 54, 55, 4, 31, 30, 29, 65, 45, 1]
# 2182.0
# [1, 2, 5, 25, 27, 6, 7, 9, 11, 10, 58, 61, 59, 8, 57, 56, 70, 3, 4, 0, 28, 64, 17, 66, 14, 13, 12, 15, 16, 21, 22, 18, 19, 20, 23, 60, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 38, 36, 43, 42, 32, 26, 24, 29, 30, 31, 65, 44, 45, 53, 52, 54, 55, 1]
# 2160.0
# [1, 2, 70, 3, 4, 5, 0, 28, 25, 27, 6, 7, 9, 11, 10, 58, 61, 59, 8, 57, 56, 52, 46, 62, 49, 48, 51, 50, 67, 47, 39, 40, 68, 54, 55, 53, 44, 43, 42, 41, 37, 63, 38, 36, 34, 35, 69, 60, 33, 32, 26, 22, 64, 17, 66, 14, 13, 12, 15, 16, 18, 21, 23, 19, 20, 24, 29, 30, 31, 65, 45, 1]
# 2206.0

# %%
for d in range(0,5):
    graph, solution = MMAS_TSP(graph,70,1000,stats_file,args_MMAS)
    besttour = solution.getTour()
    print(besttour)
    print(solution.getTourLength())
# Out:
# [1, 2, 5, 0, 28, 64, 17, 66, 14, 12, 15, 16, 18, 21, 22, 19, 20, 23, 60, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 42, 32, 26, 24, 25, 27, 6, 7, 9, 13, 11, 10, 58, 61, 59, 8, 57, 56, 70, 3, 4, 30, 29, 31, 65, 44, 43, 38, 36, 54, 55, 52, 53, 45, 1]
# 2245.0
# [1, 2, 5, 0, 28, 25, 27, 6, 7, 9, 11, 10, 58, 61, 57, 56, 70, 3, 4, 8, 59, 52, 46, 62, 54, 55, 53, 44, 43, 42, 41, 37, 63, 40, 68, 49, 48, 51, 50, 67, 47, 39, 38, 36, 34, 35, 69, 60, 33, 32, 26, 22, 17, 64, 66, 14, 13, 12, 15, 16, 18, 21, 23, 19, 20, 24, 29, 30, 31, 65, 45, 1]
# 2217.0
# [1, 2, 5, 0, 28, 24, 26, 22, 18, 21, 17, 64, 25, 27, 6, 7, 9, 13, 66, 14, 12, 15, 16, 19, 20, 23, 60, 32, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 38, 36, 43, 42, 54, 55, 56, 70, 3, 4, 8, 59, 57, 58, 61, 11, 10, 52, 53, 44, 65, 45, 30, 29, 31, 1]
# 2204.0
# [1, 2, 5, 0, 28, 24, 26, 22, 18, 21, 17, 64, 25, 27, 6, 7, 9, 13, 14, 12, 15, 16, 19, 20, 23, 60, 33, 32, 34, 35, 69, 41, 37, 63, 40, 68, 46, 62, 52, 53, 44, 65, 43, 42, 38, 36, 39, 47, 48, 51, 50, 67, 49, 54, 55, 56, 70, 3, 4, 8, 59, 57, 58, 61, 11, 10, 66, 29, 30, 31, 45, 1]
# 2238.0
# [1, 2, 5, 25, 27, 6, 7, 9, 11, 10, 58, 61, 57, 56, 70, 3, 4, 8, 59, 0, 28, 64, 17, 66, 14, 12, 13, 15, 16, 18, 19, 20, 21, 22, 23, 60, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 38, 36, 42, 43, 32, 26, 24, 29, 30, 31, 65, 44, 45, 53, 52, 54, 55, 1]
# 2194.0

# %%
for d in range(0,5):
    graph, solution = ASRANK_TSP(graph,70,1000,stats_file,args_ASRANK)
    besttour = solution.getTour()
    print(besttour)
    print(solution.getTourLength())
# Out:
# [1, 2, 5, 0, 28, 24, 26, 22, 18, 21, 14, 12, 15, 16, 17, 64, 25, 27, 6, 7, 9, 11, 10, 58, 61, 59, 57, 56, 70, 3, 4, 8, 13, 66, 19, 20, 23, 60, 33, 34, 35, 69, 41, 37, 63, 40, 68, 46, 62, 54, 55, 53, 44, 43, 42, 32, 36, 38, 39, 47, 48, 51, 50, 67, 49, 29, 30, 31, 65, 45, 52, 1]
# 2368.0
# [1, 2, 4, 57, 58, 61, 59, 8, 7, 9, 11, 10, 14, 12, 15, 16, 21, 22, 17, 64, 24, 26, 28, 0, 65, 44, 43, 42, 41, 37, 63, 40, 68, 46, 62, 54, 55, 56, 70, 3, 5, 25, 27, 6, 13, 66, 18, 19, 20, 23, 60, 33, 32, 34, 35, 69, 38, 36, 39, 47, 48, 51, 50, 67, 49, 52, 53, 45, 31, 30, 29, 1]
# 2323.0
# [1, 2, 70, 3, 8, 7, 9, 11, 10, 13, 66, 14, 12, 15, 16, 18, 19, 20, 21, 22, 17, 64, 28, 0, 65, 44, 43, 42, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 52, 53, 56, 4, 5, 25, 27, 6, 24, 26, 33, 32, 23, 60, 36, 38, 39, 47, 48, 51, 50, 67, 49, 54, 55, 57, 58, 61, 59, 31, 30, 29, 45, 1]
# 2355.0
# [1, 2, 5, 0, 28, 64, 17, 66, 14, 12, 15, 16, 18, 21, 22, 19, 20, 23, 60, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 38, 36, 32, 26, 25, 27, 6, 7, 9, 11, 10, 58, 61, 56, 70, 3, 4, 8, 59, 57, 52, 53, 44, 65, 43, 42, 54, 55, 13, 24, 29, 30, 31, 45, 1]
# 2302.0
# [1, 2, 5, 25, 27, 6, 7, 9, 11, 10, 58, 61, 57, 59, 8, 4, 18, 21, 22, 64, 17, 14, 13, 66, 12, 15, 16, 19, 20, 23, 60, 33, 35, 34, 69, 41, 37, 63, 40, 68, 46, 62, 49, 48, 51, 50, 67, 47, 39, 38, 32, 26, 24, 28, 0, 29, 30, 31, 65, 44, 43, 42, 36, 54, 55, 56, 70, 3, 52, 53, 45, 1]
# 2349.0
