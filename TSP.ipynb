# %%
import numpy as np
import pandas as pd
import networkx as nx
import traceback
import os
import matplotlib.pyplot as plt
import math
from ant_defs import Ant
import time
import tsplib95
from ant_defs import observer
from ant_defs import makestatsfile

# %%
def findbest(pop: list):
    best = Ant(0)
    best.setTourLength(100000000.0)
    for ant in pop:
        if ant.isTourViable():
            if ant < best:
                best = ant
    return best

# %% [markdown]
# ==============================================================================

# %% [markdown]
# ANT SYSTEM

# %% [markdown]
# ======================================================================================

# %%
#TODO; THIS SELECTION IS IN SUPER HELL
# TO REWRITW
def ASNextNodeSelection(graph: nx.DiGraph,viable_paths: list,visited: list,args: dict):
    psum = 0
    pvals = []
    for node in viable_paths:
        tmp = math.pow(graph[visited[-1]][node]["heuristic"],args['heuristic_preference']) + math.pow(graph[visited[-1]][node]["pheromone"],args['pheromone_preference'])
        pvals.append(tmp)
    s = np.sum(pvals)
    probs = [x/s for x in pvals]
    #print(probs)
    next_node = np.random.choice(a=viable_paths,p=probs,replace=False)
    #next_node = viable_paths[np.argmax(probs)]
    #print(next_node)
    #return viable_paths[np.argmax(pvals)]
    return next_node

def ASGlobalUpdate(graph: nx.DiGraph,population: list, args: dict) -> nx.DiGraph:
    for ant in population:
        #proper solutions only
        if ant.isTourViable(): 
            tour = ant.getTour()
            startnodes = tour[:-1]
            endnodes = tour[1:]
            for s,n in zip(startnodes,endnodes):
                graph[s][n]["delta"] = graph[s][n]["delta"] + (args['Qval'] / ant.getTourLength())
    evap_coef = 1-args['evaporation']
    for u, v, weight in graph.edges(data="pheromone"):
        graph[u][v]["pheromone"] = evap_coef*graph[u][v]["pheromone"] + graph[u][v]["delta"]
    nx.set_edge_attributes(graph,0.0,"delta")
    return graph

# %%
def AntSystemTSP(problem: nx.DiGraph, pop_count: int, max_cycles: int,stats_file, args: dict) -> Ant:
    start = time.time()
    best_solution_cycle = -1
    stagnation = 0
    consecutive_same_best = 0
    argslocal = args
    problem = problem
    nx.set_edge_attributes(problem,args['startpheromone'],"pheromone")
    population = []
    globalbest = Ant(1)
    globalbest.setTourLength(100000000.0)
    argslocal['globalbest'] = globalbest
    localbest = Ant(1)
    localbest.setTourLength(100000000.0)
    for i in range(0,max_cycles):
        population = []
        for k in range(0,pop_count):
            population.append(Ant(1))
        for j in range(0,len(problem)-1):
            for ant in population:
                visited = ant.getTour()
                # i forgot wtf is going on here
                # ok so we assume the last visited node is our starting node
                # and NX Graph gives us a list of all its neighbours
                # and we check if we were already there
                viable_paths = [x for x in [n for n in problem[visited[-1]]] if x not in visited]
                if len(viable_paths) == 0:
                    if j < len(problem)-1:
                        print("ant invalidated")
                        ant.invalidateTour()
                    pass
                else:
                    next_node = ASNextNodeSelection(problem,viable_paths,visited,argslocal)
                    ant.move(next_node,problem[visited[-1]][next_node]["weight"])
                #ants have moved 1 node ahead
            #most ants now have a solution ready
        for ant in population:
            visited = ant.getTour()
            ant.move(visited[0],problem[visited[-1]][visited[0]]["weight"])
        #post cycle pheromone updates and solution assesment
        #review population
        poptours = [x.getTourLength() for x in population if x.isTourViable()]
        localbest = findbest(population)
        #print(localbest.getTourLength())
        #print(consecutive_same_best)
        if localbest < globalbest:
            globalbest = localbest
            argslocal['globalbest'] = globalbest
            best_solution_cycle = i
            consecutive_same_best = 0
        else:
            consecutive_same_best = consecutive_same_best + 1
        if consecutive_same_best > 10:
            stagnation = i
            break
        problem = ASGlobalUpdate(problem,population,argslocal)
    end = time.time()
    extime = end - start
    observer(stats_file,'AS', pop_count, stagnation, best_solution_cycle,globalbest, extime, argslocal)
    return problem, globalbest

# %% [markdown]
# =====================================================================================

# %% [markdown]
# ANT COLONY ACO

# %% [markdown]
# =====================================================================================

# %%
def ACONextNodeSelection(graph: nx.DiGraph,viable_paths: list,visited: list,args: dict):
    pvals = []
    if args['selectionTypeConst'] > np.random.uniform():
        for node in viable_paths:
            tmp = graph[visited[-1]][node]["heuristic"] + math.pow(graph[visited[-1]][node]["pheromone"],args['heuristic_preference'])
            pvals.append(tmp)
        return viable_paths[np.argmax(pvals)]
    else:
        return ASNextNodeSelection(graph,viable_paths,visited,args)

def ACOGlobalPheromoneUpdate(graph: nx.DiGraph,population: list, args: dict):
    evap_coef = 1-args['evaporation']
    best = args['globalbest']
    tour = best.getTour()
    startnodes = tour[:-1]
    endnodes = tour[1:]
    for s,n in zip(startnodes,endnodes):
        graph[s][n]["delta"] += math.pow(best.getTourLength(),-1)
    for u, v, weight in graph.edges(data="pheromone"):
        graph[u][v]["pheromone"] = (evap_coef*graph[u][v]["pheromone"]) + (args['evaporation']*graph[u][v]["delta"])
    nx.set_edge_attributes(graph,0.0,"delta")
    return graph

def ACOLocalUpdateTau0(graph: nx.DiGraph, lastnode, newnode, taboo: list, args: dict):
    evap_coef = 1-args['evaporation']
    one = evap_coef*graph[lastnode][newnode]['pheromone']
    two = args['evaporation']*args['startpheromone']
    graph[lastnode][newnode]["pheromone"] = one + two
    return graph

def ACOLocalUpdateQlearning(graph: nx.DiGraph, lastnode, newnode, taboo: list, args: dict):
    evap_coef = 1-args['evaporation']
    nextnodes = [x for x in [n for n in graph[newnode]] if x not in taboo]
    if len(nextnodes) == 0:
        return ACOLocalUpdateTau0(graph,lastnode,newnode,taboo,args)
    else:
        nextphero = []
        for node in nextnodes:
            nextphero.append(graph[newnode][node]['pheromone'])
        delta = args['ACS_qlearn_gamma']*np.max(nextphero)
        one = evap_coef*graph[lastnode][newnode]['pheromone']
        two = args['evaporation']*delta
        graph[lastnode][newnode]["pheromone"] = one + two
        return graph

# %%
def ACO_TSP(problem: nx.DiGraph, pop_count: int, max_cycles: int,stats_file, args: dict) -> Ant:
    start = time.time()
    best_solution_cycle = -1
    stagnation = 0
    consecutive_same_best = 0
    argslocal = args
    problem = problem
    nx.set_edge_attributes(problem,args['startpheromone'],"pheromone")
    population = []
    globalbest = Ant(0)
    globalbest.setTourLength(100000000.0)
    argslocal['globalbest'] = globalbest
    localbest = Ant(0)
    localbest.setTourLength(100000000.0)
    for i in range(0,max_cycles):
        population = []
        for k in range(0,pop_count):
            population.append(Ant(1))
        for j in range(0,len(problem)-1):
            for ant in population:
                visited = ant.getTour()
                viable_paths = [x for x in [n for n in problem[visited[-1]]] if x not in visited]
                if len(viable_paths) == 0:
                    if j < len(problem)-1:
                        ant.invalidateTour()
                    pass
                else:
                    next_node = ACONextNodeSelection(problem,viable_paths,visited,argslocal)
                    ACOLocalUpdateQlearning(problem,visited[-1],next_node,visited,argslocal)
                    ant.move(next_node,problem[visited[-1]][next_node]["weight"])
                #ants have moved 1 node ahead
            #most ants now have a solution ready
        for ant in population:
            visited = ant.getTour()
            ant.move(visited[0],problem[visited[-1]][visited[0]]["weight"])
        #post cycle pheromone updates and solution assesment
        #review population
        localbest = findbest(population)
        if localbest < globalbest:
            globalbest = localbest
            argslocal['globalbest'] = globalbest
            best_solution_cycle = i
            consecutive_same_best = 0
        else:
            consecutive_same_best = consecutive_same_best + 1
        if consecutive_same_best > 10:
            stagnation = i
            break
        problem = ACOGlobalPheromoneUpdate(problem,population,argslocal)
    end = time.time()
    extime = end - start
    observer(stats_file,'ACO', pop_count, stagnation, best_solution_cycle,globalbest, extime, argslocal)
    return problem, globalbest

# %% [markdown]
# =====================================================================================

# %% [markdown]
# MMAS

# %% [markdown]
# =====================================================================================

# %%
def MMAStaumax(graph: nx.DiGraph, bestlength: float, args: dict):
    one = 1/(1-args['evaporation'])
    two = 1/bestlength
    max_pheromone = one * two
    args['max_pheromone'] = max_pheromone
    return args

def MMAStaumin(graph: nx.DiGraph, args: dict):
    n = graph.number_of_nodes()
    p = args['best_pheromone_selection_prob']**(1/n)
    av = n/2
    min_pheromone = (args['max_pheromone']*(1-p))/((av-1)*p)
    args['min_pheromone'] = min_pheromone
    return args

def MMASTrailSmoothing(graph: nx.DiGraph, args: dict):
    for u, v, pheromone in graph.edges(data="pheromone"):
        graph[u][v]["pheromone"] = pheromone + args['smoothing_coef']*(args['max_pheromone']-pheromone)
    return graph

def MMASGlobalUpdate(graph: nx.DiGraph,localbest, args: dict) -> nx.DiGraph:
        #proper solutions only
    tour = localbest.getTour()
    startnodes = tour[:-1]
    endnodes = tour[1:]
    for s,n in zip(startnodes,endnodes):
        graph[s][n]["delta"] += args['Qval'] / localbest.getTourLength()
    evap_coef = 1-args['evaporation']
    for u, v, weight in graph.edges(data="pheromone"):
        new_pheromone = evap_coef*graph[u][v]["pheromone"] + graph[u][v]["delta"]
        if new_pheromone > args['max_pheromone']:
            new_pheromone = args['max_pheromone']
        elif new_pheromone < args['min_pheromone']:
            new_pheromone = args['min_pheromone']
        graph[u][v]["pheromone"] = new_pheromone
    nx.set_edge_attributes(graph,0.0,"delta")
    return graph

# %%
def MMAS_TSP(problem: nx.DiGraph, pop_count: int, max_cycles: int,stats_file, args: dict) -> Ant:
    start = time.time()
    max_stagnations = 2
    current_stagnations = 0
    best_solution_cycle = -1
    stagnation = 0
    consecutive_same_best = 0
    argslocal = args
    problem = problem
    nx.set_edge_attributes(problem,args['startpheromone'],"pheromone")
    population = []
    globalbest = Ant(0)
    globalbest.setTourLength(100000000.0)
    argslocal['globalbest'] = globalbest
    localbest = Ant(0)
    localbest.setTourLength(100000000.0)
    for i in range(0,max_cycles):
        population = []
        for k in range(0,pop_count):
            population.append(Ant(1))
        for j in range(0,len(problem)-1):
            for ant in population:
                visited = ant.getTour()
                # i forgot wtf is going on here
                # ok so we assume the last visited node is our starting node
                # and NX Graph gives us a list of all its neighbours
                # and we check if we were already there
                viable_paths = [x for x in [n for n in problem[visited[-1]]] if x not in visited]
                if len(viable_paths) == 0:
                    if j < len(problem)-1:
                        ant.invalidateTour()
                    pass
                else:
                    next_node = ASNextNodeSelection(problem,viable_paths,visited,argslocal)
                    ant.move(next_node,problem[visited[-1]][next_node]["weight"])
                #ants have moved 1 node ahead
            #most ants now have a solution ready
        for ant in population:
            visited = ant.getTour()
            ant.move(visited[0],problem[visited[-1]][visited[0]]["weight"])
        #post cycle pheromone updates and solution assesment
        #review population
        localbest = findbest(population)
        if localbest < globalbest:
            globalbest = localbest
            argslocal['globalbest'] = globalbest
            best_solution_cycle = i
            consecutive_same_best = 0
        else:
            consecutive_same_best = consecutive_same_best + 1
        argslocal = MMAStaumax(problem,globalbest.getTourLength(),argslocal)
        argslocal = MMAStaumin(problem,argslocal)
        problem = MMASGlobalUpdate(problem,localbest,argslocal)
        poptours = [x.getTourLength() for x in population if x.isTourViable()]
        if consecutive_same_best > 10:
            stagnation = i
            problem = MMASTrailSmoothing(problem,argslocal)
            consecutive_same_best = 0
            current_stagnations = current_stagnations + 1
        if current_stagnations > max_stagnations:
            break
        # TODO: Find way to detect convergence and stagnation to insert trail smoothing here
    end = time.time()
    extime = end - start
    observer(stats_file,'MMAS', pop_count, stagnation, best_solution_cycle,globalbest, extime, argslocal)
    return problem, globalbest

# %% [markdown]
# =====================================================================================

# %% [markdown]
# ASRANK

# %% [markdown]
# =====================================================================================

# %%
def ASRANKGlobalUpdate(graph,population,args):
    good_solutions = [x for x in population if x.isTourViable()]
    good_solutions.sort(reverse=True)
    ranks = args['elite_multiplier']-1
    used_solutions = good_solutions[-ranks:]

    for rank, ant in enumerate(used_solutions):
        r_rank = rank + 1
        tour = ant.getTour()
        startnodes = tour[:-1]
        endnodes = tour[1:]
        for s,n in zip(startnodes,endnodes):
            graph[s][n]["delta"] += (args['Qval'] / ant.getTourLength())*r_rank
    best = args['globalbest']   
    besttour = best.getTour()
    startnodes = besttour[:-1]
    endnodes = besttour[1:]
    for s,n in zip(startnodes,endnodes):
        graph[s][n]["elite_delta"] += (args['Qval'] / best.getTourLength())*args['elite_multiplier']
    evap_coef = 1-args['evaporation']
    for u, v, weight in graph.edges(data="pheromone"):
        graph[u][v]["pheromone"] = evap_coef*graph[u][v]["pheromone"] + graph[u][v]["delta"] + graph[u][v]["elite_delta"]
    nx.set_edge_attributes(graph,0.0,"delta")
    nx.set_edge_attributes(graph,0.0,"elite_delta")
    return graph

# %%
def ASRANK_TSP(problem: nx.DiGraph, pop_count: int, max_cycles: int, stats_file, args: dict) -> Ant:
    start = time.time()
    best_solution_cycle = -1
    stagnation = 0
    consecutive_same_best = 0
    argslocal = args
    problem = problem
    nx.set_edge_attributes(problem,args['startpheromone'],"pheromone")
    nx.set_edge_attributes(problem,0.0,"elite_delta")
    population = []
    globalbest = Ant(0)
    globalbest.setTourLength(100000000.0)
    argslocal['globalbest'] = globalbest
    localbest = Ant(0)
    localbest.setTourLength(100000000.0)
    for i in range(0,max_cycles):
        population = []
        for k in range(0,pop_count):
            population.append(Ant(1))
        for j in range(0,len(problem)-1):
            for ant in population:
                visited = ant.getTour()
                # i forgot wtf is going on here
                # ok so we assume the last visited node is our starting node
                # and NX Graph gives us a list of all its neighbours
                # and we check if we were already there
                viable_paths = [x for x in [n for n in problem[visited[-1]]] if x not in visited]
                if len(viable_paths) == 0:
                    if j < len(problem)-1:
                        ant.invalidateTour()
                    pass
                else:
                    next_node = ASNextNodeSelection(problem,viable_paths,visited,argslocal)
                    ant.move(next_node,problem[visited[-1]][next_node]["weight"])
                #ants have moved 1 node ahead
            #most ants now have a solution ready
        #post cycle pheromone updates and solution assesment
        #review population
        for ant in population:
            visited = ant.getTour()
            ant.move(visited[0],problem[visited[-1]][visited[0]]["weight"])
        localbest = findbest(population)
        if localbest < globalbest:
            globalbest = localbest
            argslocal['globalbest'] = globalbest
            best_solution_cycle = i
            consecutive_same_best = 0
        else:
            consecutive_same_best = consecutive_same_best + 1
        if consecutive_same_best > 10:
            stagnation = i
            break
        problem = ASRANKGlobalUpdate(problem,population,argslocal)
    end = time.time()
    extime = end - start
    observer(stats_file,'ASRANK', pop_count, stagnation, best_solution_cycle,globalbest, extime, argslocal)
    return problem, globalbest

# %%
stats_file = makestatsfile('bur26a.csv')

# %%
p = tsplib95.load('ft53.atsp')
p.edge_weights  
graph = p.get_graph()
nx.set_edge_attributes(graph,1.0,"pheromone")
nx.set_edge_attributes(graph,'b',"color")
nx.set_edge_attributes(graph,0.0,"heuristic")
nx.set_edge_attributes(graph,0.0,"delta")

for u, v, weight in graph.edges(data="weight"):
    if(weight is not None and weight != 0):
        print(f'source {u}, dest {v}, weight {weight}')
        graph[u][v]["heuristic"] = 1/weight

# %%
# from QAPInstances import getBur26a
# burA, burB = getBur26a()
# burA = np.matrix(burA)
# burB = np.matrix(burB)
# vectA = burA.sum(axis=1)
# vectB = burB.sum(axis=1)
# graphweights = np.dot(vectA,vectB.T)
# graph = nx.from_numpy_matrix(graphweights, create_using=nx.DiGraph)
# nx.set_edge_attributes(graph,1.0,"pheromone")
# nx.set_edge_attributes(graph,'b',"color")
# nx.set_edge_attributes(graph,0.0,"heuristic")
# nx.set_edge_attributes(graph,0.0,"delta")

# for u, v, weight in graph.edges(data="weight"):
#     if(weight is not None and weight != 0):
#         print(f'source {u}, dest {v}, weight {weight}')
#         graph[u][v]["heuristic"] = 1/weight
# Out:
# source 0, dest 0, weight 10606050
# source 0, dest 1, weight 3794175
# source 0, dest 2, weight 5366025
# source 0, dest 3, weight 8076600
# source 0, dest 4, weight 27004950
# source 0, dest 5, weight 2327850
# source 0, dest 6, weight 4969125
# source 0, dest 7, weight 6811875
# source 0, dest 8, weight 15239700
# source 0, dest 9, weight 532350
# source 0, dest 10, weight 2434950
# source 0, dest 11, weight 6455925
# source 0, dest 12, weight 3600450
# source 0, dest 13, weight 11681775
# source 0, dest 14, weight 4972275
# source 0, dest 15, weight 1970325
# source 0, dest 16, weight 28350
# source 0, dest 17, weight 9913050
# source 0, dest 18, weight 9753975
# source 0, dest 19, weight 8380575
# source 0, dest 20, weight 6728400
# source 0, dest 21, weight 1855350
# source 0, dest 22, weight 2549925
# source 0, dest 23, weight 88200
# source 0, dest 24, weight 141750
# source 0, dest 25, weight 2230200
# source 1, dest 0, weight 10606050
# source 1, dest 1, weight 3794175
# source 1, dest 2, weight 5366025
# source 1, dest 3, weight 8076600
# source 1, dest 4, weight 27004950
# source 1, dest 5, weight 2327850
# source 1, dest 6, weight 4969125
# source 1, dest 7, weight 6811875
# source 1, dest 8, weight 15239700
# source 1, dest 9, weight 532350
# source 1, dest 10, weight 2434950
# source 1, dest 11, weight 6455925
# source 1, dest 12, weight 3600450
# source 1, dest 13, weight 11681775
# source 1, dest 14, weight 4972275
# source 1, dest 15, weight 1970325
# source 1, dest 16, weight 28350
# source 1, dest 17, weight 9913050
# source 1, dest 18, weight 9753975
# source 1, dest 19, weight 8380575
# source 1, dest 20, weight 6728400
# source 1, dest 21, weight 1855350
# source 1, dest 22, weight 2549925
# source 1, dest 23, weight 88200
# source 1, dest 24, weight 141750
# source 1, dest 25, weight 2230200
# source 2, dest 0, weight 10606050
# source 2, dest 1, weight 3794175
# source 2, dest 2, weight 5366025
# source 2, dest 3, weight 8076600
# source 2, dest 4, weight 27004950
# source 2, dest 5, weight 2327850
# source 2, dest 6, weight 4969125
# source 2, dest 7, weight 6811875
# source 2, dest 8, weight 15239700
# source 2, dest 9, weight 532350
# source 2, dest 10, weight 2434950
# source 2, dest 11, weight 6455925
# source 2, dest 12, weight 3600450
# source 2, dest 13, weight 11681775
# source 2, dest 14, weight 4972275
# source 2, dest 15, weight 1970325
# source 2, dest 16, weight 28350
# source 2, dest 17, weight 9913050
# source 2, dest 18, weight 9753975
# source 2, dest 19, weight 8380575
# source 2, dest 20, weight 6728400
# source 2, dest 21, weight 1855350
# source 2, dest 22, weight 2549925
# source 2, dest 23, weight 88200
# source 2, dest 24, weight 141750
# source 2, dest 25, weight 2230200
# source 3, dest 0, weight 10733996
# source 3, dest 1, weight 3839946
# source 3, dest 2, weight 5430758
# source 3, dest 3, weight 8174032
# source 3, dest 4, weight 27330724
# source 3, dest 5, weight 2355932
# source 3, dest 6, weight 5029070
# source 3, dest 7, weight 6894050
# source 3, dest 8, weight 15423544
# source 3, dest 9, weight 538772
# source 3, dest 10, weight 2464324
# source 3, dest 11, weight 6533806
# source 3, dest 12, weight 3643884
# source 3, dest 13, weight 11822698
# source 3, dest 14, weight 5032258
# source 3, dest 15, weight 1994094
# source 3, dest 16, weight 28692
# source 3, dest 17, weight 10032636
# source 3, dest 18, weight 9871642
# source 3, dest 19, weight 8481674
# source 3, dest 20, weight 6809568
# source 3, dest 21, weight 1877732
# source 3, dest 22, weight 2580686
# source 3, dest 23, weight 89264
# source 3, dest 24, weight 143460
# source 3, dest 25, weight 2257104
# source 4, dest 0, weight 10599316
# source 4, dest 1, weight 3791766
# source 4, dest 2, weight 5362618
# source 4, dest 3, weight 8071472
# source 4, dest 4, weight 26987804
# source 4, dest 5, weight 2326372
# source 4, dest 6, weight 4965970
# source 4, dest 7, weight 6807550
# source 4, dest 8, weight 15230024
# source 4, dest 9, weight 532012
# source 4, dest 10, weight 2433404
# source 4, dest 11, weight 6451826
# source 4, dest 12, weight 3598164
# source 4, dest 13, weight 11674358
# source 4, dest 14, weight 4969118
# source 4, dest 15, weight 1969074
# source 4, dest 16, weight 28332
# source 4, dest 17, weight 9906756
# source 4, dest 18, weight 9747782
# source 4, dest 19, weight 8375254
# source 4, dest 20, weight 6724128
# source 4, dest 21, weight 1854172
# source 4, dest 22, weight 2548306
# source 4, dest 23, weight 88144
# source 4, dest 24, weight 141660
# source 4, dest 25, weight 2228784
# source 5, dest 0, weight 10329956
# source 5, dest 1, weight 3695406
# source 5, dest 2, weight 5226338
# source 5, dest 3, weight 7866352
# source 5, dest 4, weight 26301964
# source 5, dest 5, weight 2267252
# source 5, dest 6, weight 4839770
# source 5, dest 7, weight 6634550
# source 5, dest 8, weight 14842984
# source 5, dest 9, weight 518492
# source 5, dest 10, weight 2371564
# source 5, dest 11, weight 6287866
# source 5, dest 12, weight 3506724
# source 5, dest 13, weight 11377678
# source 5, dest 14, weight 4842838
# source 5, dest 15, weight 1919034
# source 5, dest 16, weight 27612
# source 5, dest 17, weight 9654996
# source 5, dest 18, weight 9500062
# source 5, dest 19, weight 8162414
# source 5, dest 20, weight 6553248
# source 5, dest 21, weight 1807052
# source 5, dest 22, weight 2483546
# source 5, dest 23, weight 85904
# source 5, dest 24, weight 138060
# source 5, dest 25, weight 2172144
# source 6, dest 0, weight 10329956
# source 6, dest 1, weight 3695406
# source 6, dest 2, weight 5226338
# source 6, dest 3, weight 7866352
# source 6, dest 4, weight 26301964
# source 6, dest 5, weight 2267252
# source 6, dest 6, weight 4839770
# source 6, dest 7, weight 6634550
# source 6, dest 8, weight 14842984
# source 6, dest 9, weight 518492
# source 6, dest 10, weight 2371564
# source 6, dest 11, weight 6287866
# source 6, dest 12, weight 3506724
# source 6, dest 13, weight 11377678
# source 6, dest 14, weight 4842838
# source 6, dest 15, weight 1919034
# source 6, dest 16, weight 27612
# source 6, dest 17, weight 9654996
# source 6, dest 18, weight 9500062
# source 6, dest 19, weight 8162414
# source 6, dest 20, weight 6553248
# source 6, dest 21, weight 1807052
# source 6, dest 22, weight 2483546
# source 6, dest 23, weight 85904
# source 6, dest 24, weight 138060
# source 6, dest 25, weight 2172144
# source 7, dest 0, weight 10121202
# source 7, dest 1, weight 3620727
# source 7, dest 2, weight 5120721
# source 7, dest 3, weight 7707384
# source 7, dest 4, weight 25770438
# source 7, dest 5, weight 2221434
# source 7, dest 6, weight 4741965
# source 7, dest 7, weight 6500475
# source 7, dest 8, weight 14543028
# source 7, dest 9, weight 508014
# source 7, dest 10, weight 2323638
# source 7, dest 11, weight 6160797
# source 7, dest 12, weight 3435858
# source 7, dest 13, weight 11147751
# source 7, dest 14, weight 4744971
# source 7, dest 15, weight 1880253
# source 7, dest 16, weight 27054
# source 7, dest 17, weight 9459882
# source 7, dest 18, weight 9308079
# source 7, dest 19, weight 7997463
# source 7, dest 20, weight 6420816
# source 7, dest 21, weight 1770534
# source 7, dest 22, weight 2433357
# source 7, dest 23, weight 84168
# source 7, dest 24, weight 135270
# source 7, dest 25, weight 2128248
# source 8, dest 0, weight 10121202
# source 8, dest 1, weight 3620727
# source 8, dest 2, weight 5120721
# source 8, dest 3, weight 7707384
# source 8, dest 4, weight 25770438
# source 8, dest 5, weight 2221434
# source 8, dest 6, weight 4741965
# source 8, dest 7, weight 6500475
# source 8, dest 8, weight 14543028
# source 8, dest 9, weight 508014
# source 8, dest 10, weight 2323638
# source 8, dest 11, weight 6160797
# source 8, dest 12, weight 3435858
# source 8, dest 13, weight 11147751
# source 8, dest 14, weight 4744971
# source 8, dest 15, weight 1880253
# source 8, dest 16, weight 27054
# source 8, dest 17, weight 9459882
# source 8, dest 18, weight 9308079
# source 8, dest 19, weight 7997463
# source 8, dest 20, weight 6420816
# source 8, dest 21, weight 1770534
# source 8, dest 22, weight 2433357
# source 8, dest 23, weight 84168
# source 8, dest 24, weight 135270
# source 8, dest 25, weight 2128248
# source 9, dest 0, weight 9986522
# source 9, dest 1, weight 3572547
# source 9, dest 2, weight 5052581
# source 9, dest 3, weight 7604824
# source 9, dest 4, weight 25427518
# source 9, dest 5, weight 2191874
# source 9, dest 6, weight 4678865
# source 9, dest 7, weight 6413975
# source 9, dest 8, weight 14349508
# source 9, dest 9, weight 501254
# source 9, dest 10, weight 2292718
# source 9, dest 11, weight 6078817
# source 9, dest 12, weight 3390138
# source 9, dest 13, weight 10999411
# source 9, dest 14, weight 4681831
# source 9, dest 15, weight 1855233
# source 9, dest 16, weight 26694
# source 9, dest 17, weight 9334002
# source 9, dest 18, weight 9184219
# source 9, dest 19, weight 7891043
# source 9, dest 20, weight 6335376
# source 9, dest 21, weight 1746974
# source 9, dest 22, weight 2400977
# source 9, dest 23, weight 83048
# source 9, dest 24, weight 133470
# source 9, dest 25, weight 2099928
# source 10, dest 0, weight 10478104
# source 10, dest 1, weight 3748404
# source 10, dest 2, weight 5301292
# source 10, dest 3, weight 7979168
# source 10, dest 4, weight 26679176
# source 10, dest 5, weight 2299768
# source 10, dest 6, weight 4909180
# source 10, dest 7, weight 6729700
# source 10, dest 8, weight 15055856
# source 10, dest 9, weight 525928
# source 10, dest 10, weight 2405576
# source 10, dest 11, weight 6378044
# source 10, dest 12, weight 3557016
# source 10, dest 13, weight 11540852
# source 10, dest 14, weight 4912292
# source 10, dest 15, weight 1946556
# source 10, dest 16, weight 28008
# source 10, dest 17, weight 9793464
# source 10, dest 18, weight 9636308
# source 10, dest 19, weight 8279476
# source 10, dest 20, weight 6647232
# source 10, dest 21, weight 1832968
# source 10, dest 22, weight 2519164
# source 10, dest 23, weight 87136
# source 10, dest 24, weight 140040
# source 10, dest 25, weight 2203296
# source 11, dest 0, weight 10478104
# source 11, dest 1, weight 3748404
# source 11, dest 2, weight 5301292
# source 11, dest 3, weight 7979168
# source 11, dest 4, weight 26679176
# source 11, dest 5, weight 2299768
# source 11, dest 6, weight 4909180
# source 11, dest 7, weight 6729700
# source 11, dest 8, weight 15055856
# source 11, dest 9, weight 525928
# source 11, dest 10, weight 2405576
# source 11, dest 11, weight 6378044
# source 11, dest 12, weight 3557016
# source 11, dest 13, weight 11540852
# source 11, dest 14, weight 4912292
# source 11, dest 15, weight 1946556
# source 11, dest 16, weight 28008
# source 11, dest 17, weight 9793464
# source 11, dest 18, weight 9636308
# source 11, dest 19, weight 8279476
# source 11, dest 20, weight 6647232
# source 11, dest 21, weight 1832968
# source 11, dest 22, weight 2519164
# source 11, dest 23, weight 87136
# source 11, dest 24, weight 140040
# source 11, dest 25, weight 2203296
# source 12, dest 0, weight 10478104
# source 12, dest 1, weight 3748404
# source 12, dest 2, weight 5301292
# source 12, dest 3, weight 7979168
# source 12, dest 4, weight 26679176
# source 12, dest 5, weight 2299768
# source 12, dest 6, weight 4909180
# source 12, dest 7, weight 6729700
# source 12, dest 8, weight 15055856
# source 12, dest 9, weight 525928
# source 12, dest 10, weight 2405576
# source 12, dest 11, weight 6378044
# source 12, dest 12, weight 3557016
# source 12, dest 13, weight 11540852
# source 12, dest 14, weight 4912292
# source 12, dest 15, weight 1946556
# source 12, dest 16, weight 28008
# source 12, dest 17, weight 9793464
# source 12, dest 18, weight 9636308
# source 12, dest 19, weight 8279476
# source 12, dest 20, weight 6647232
# source 12, dest 21, weight 1832968
# source 12, dest 22, weight 2519164
# source 12, dest 23, weight 87136
# source 12, dest 24, weight 140040
# source 12, dest 25, weight 2203296
# source 13, dest 0, weight 10478104
# source 13, dest 1, weight 3748404
# source 13, dest 2, weight 5301292
# source 13, dest 3, weight 7979168
# source 13, dest 4, weight 26679176
# source 13, dest 5, weight 2299768
# source 13, dest 6, weight 4909180
# source 13, dest 7, weight 6729700
# source 13, dest 8, weight 15055856
# source 13, dest 9, weight 525928
# source 13, dest 10, weight 2405576
# source 13, dest 11, weight 6378044
# source 13, dest 12, weight 3557016
# source 13, dest 13, weight 11540852
# source 13, dest 14, weight 4912292
# source 13, dest 15, weight 1946556
# source 13, dest 16, weight 28008
# source 13, dest 17, weight 9793464
# source 13, dest 18, weight 9636308
# source 13, dest 19, weight 8279476
# source 13, dest 20, weight 6647232
# source 13, dest 21, weight 1832968
# source 13, dest 22, weight 2519164
# source 13, dest 23, weight 87136
# source 13, dest 24, weight 140040
# source 13, dest 25, weight 2203296
# source 14, dest 0, weight 10478104
# source 14, dest 1, weight 3748404
# source 14, dest 2, weight 5301292
# source 14, dest 3, weight 7979168
# source 14, dest 4, weight 26679176
# source 14, dest 5, weight 2299768
# source 14, dest 6, weight 4909180
# source 14, dest 7, weight 6729700
# source 14, dest 8, weight 15055856
# source 14, dest 9, weight 525928
# source 14, dest 10, weight 2405576
# source 14, dest 11, weight 6378044
# source 14, dest 12, weight 3557016
# source 14, dest 13, weight 11540852
# source 14, dest 14, weight 4912292
# source 14, dest 15, weight 1946556
# source 14, dest 16, weight 28008
# source 14, dest 17, weight 9793464
# source 14, dest 18, weight 9636308
# source 14, dest 19, weight 8279476
# source 14, dest 20, weight 6647232
# source 14, dest 21, weight 1832968
# source 14, dest 22, weight 2519164
# source 14, dest 23, weight 87136
# source 14, dest 24, weight 140040
# source 14, dest 25, weight 2203296
# source 15, dest 0, weight 10074064
# source 15, dest 1, weight 3603864
# source 15, dest 2, weight 5096872
# source 15, dest 3, weight 7671488
# source 15, dest 4, weight 25650416
# source 15, dest 5, weight 2211088
# source 15, dest 6, weight 4719880
# source 15, dest 7, weight 6470200
# source 15, dest 8, weight 14475296
# source 15, dest 9, weight 505648
# source 15, dest 10, weight 2312816
# source 15, dest 11, weight 6132104
# source 15, dest 12, weight 3419856
# source 15, dest 13, weight 11095832
# source 15, dest 14, weight 4722872
# source 15, dest 15, weight 1871496
# source 15, dest 16, weight 26928
# source 15, dest 17, weight 9415824
# source 15, dest 18, weight 9264728
# source 15, dest 19, weight 7960216
# source 15, dest 20, weight 6390912
# source 15, dest 21, weight 1762288
# source 15, dest 22, weight 2422024
# source 15, dest 23, weight 83776
# source 15, dest 24, weight 134640
# source 15, dest 25, weight 2118336
# source 16, dest 0, weight 10074064
# source 16, dest 1, weight 3603864
# source 16, dest 2, weight 5096872
# source 16, dest 3, weight 7671488
# source 16, dest 4, weight 25650416
# source 16, dest 5, weight 2211088
# source 16, dest 6, weight 4719880
# source 16, dest 7, weight 6470200
# source 16, dest 8, weight 14475296
# source 16, dest 9, weight 505648
# source 16, dest 10, weight 2312816
# source 16, dest 11, weight 6132104
# source 16, dest 12, weight 3419856
# source 16, dest 13, weight 11095832
# source 16, dest 14, weight 4722872
# source 16, dest 15, weight 1871496
# source 16, dest 16, weight 26928
# source 16, dest 17, weight 9415824
# source 16, dest 18, weight 9264728
# source 16, dest 19, weight 7960216
# source 16, dest 20, weight 6390912
# source 16, dest 21, weight 1762288
# source 16, dest 22, weight 2422024
# source 16, dest 23, weight 83776
# source 16, dest 24, weight 134640
# source 16, dest 25, weight 2118336
# source 17, dest 0, weight 10074064
# source 17, dest 1, weight 3603864
# source 17, dest 2, weight 5096872
# source 17, dest 3, weight 7671488
# source 17, dest 4, weight 25650416
# source 17, dest 5, weight 2211088
# source 17, dest 6, weight 4719880
# source 17, dest 7, weight 6470200
# source 17, dest 8, weight 14475296
# source 17, dest 9, weight 505648
# source 17, dest 10, weight 2312816
# source 17, dest 11, weight 6132104
# source 17, dest 12, weight 3419856
# source 17, dest 13, weight 11095832
# source 17, dest 14, weight 4722872
# source 17, dest 15, weight 1871496
# source 17, dest 16, weight 26928
# source 17, dest 17, weight 9415824
# source 17, dest 18, weight 9264728
# source 17, dest 19, weight 7960216
# source 17, dest 20, weight 6390912
# source 17, dest 21, weight 1762288
# source 17, dest 22, weight 2422024
# source 17, dest 23, weight 83776
# source 17, dest 24, weight 134640
# source 17, dest 25, weight 2118336
# source 18, dest 0, weight 10074064
# source 18, dest 1, weight 3603864
# source 18, dest 2, weight 5096872
# source 18, dest 3, weight 7671488
# source 18, dest 4, weight 25650416
# source 18, dest 5, weight 2211088
# source 18, dest 6, weight 4719880
# source 18, dest 7, weight 6470200
# source 18, dest 8, weight 14475296
# source 18, dest 9, weight 505648
# source 18, dest 10, weight 2312816
# source 18, dest 11, weight 6132104
# source 18, dest 12, weight 3419856
# source 18, dest 13, weight 11095832
# source 18, dest 14, weight 4722872
# source 18, dest 15, weight 1871496
# source 18, dest 16, weight 26928
# source 18, dest 17, weight 9415824
# source 18, dest 18, weight 9264728
# source 18, dest 19, weight 7960216
# source 18, dest 20, weight 6390912
# source 18, dest 21, weight 1762288
# source 18, dest 22, weight 2422024
# source 18, dest 23, weight 83776
# source 18, dest 24, weight 134640
# source 18, dest 25, weight 2118336
# source 19, dest 0, weight 10558912
# source 19, dest 1, weight 3777312
# source 19, dest 2, weight 5342176
# source 19, dest 3, weight 8040704
# source 19, dest 4, weight 26884928
# source 19, dest 5, weight 2317504
# source 19, dest 6, weight 4947040
# source 19, dest 7, weight 6781600
# source 19, dest 8, weight 15171968
# source 19, dest 9, weight 529984
# source 19, dest 10, weight 2424128
# source 19, dest 11, weight 6427232
# source 19, dest 12, weight 3584448
# source 19, dest 13, weight 11629856
# source 19, dest 14, weight 4950176
# source 19, dest 15, weight 1961568
# source 19, dest 16, weight 28224
# source 19, dest 17, weight 9868992
# source 19, dest 18, weight 9710624
# source 19, dest 19, weight 8343328
# source 19, dest 20, weight 6698496
# source 19, dest 21, weight 1847104
# source 19, dest 22, weight 2538592
# source 19, dest 23, weight 87808
# source 19, dest 24, weight 141120
# source 19, dest 25, weight 2220288
# source 20, dest 0, weight 10558912
# source 20, dest 1, weight 3777312
# source 20, dest 2, weight 5342176
# source 20, dest 3, weight 8040704
# source 20, dest 4, weight 26884928
# source 20, dest 5, weight 2317504
# source 20, dest 6, weight 4947040
# source 20, dest 7, weight 6781600
# source 20, dest 8, weight 15171968
# source 20, dest 9, weight 529984
# source 20, dest 10, weight 2424128
# source 20, dest 11, weight 6427232
# source 20, dest 12, weight 3584448
# source 20, dest 13, weight 11629856
# source 20, dest 14, weight 4950176
# source 20, dest 15, weight 1961568
# source 20, dest 16, weight 28224
# source 20, dest 17, weight 9868992
# source 20, dest 18, weight 9710624
# source 20, dest 19, weight 8343328
# source 20, dest 20, weight 6698496
# source 20, dest 21, weight 1847104
# source 20, dest 22, weight 2538592
# source 20, dest 23, weight 87808
# source 20, dest 24, weight 141120
# source 20, dest 25, weight 2220288
# source 21, dest 0, weight 10558912
# source 21, dest 1, weight 3777312
# source 21, dest 2, weight 5342176
# source 21, dest 3, weight 8040704
# source 21, dest 4, weight 26884928
# source 21, dest 5, weight 2317504
# source 21, dest 6, weight 4947040
# source 21, dest 7, weight 6781600
# source 21, dest 8, weight 15171968
# source 21, dest 9, weight 529984
# source 21, dest 10, weight 2424128
# source 21, dest 11, weight 6427232
# source 21, dest 12, weight 3584448
# source 21, dest 13, weight 11629856
# source 21, dest 14, weight 4950176
# source 21, dest 15, weight 1961568
# source 21, dest 16, weight 28224
# source 21, dest 17, weight 9868992
# source 21, dest 18, weight 9710624
# source 21, dest 19, weight 8343328
# source 21, dest 20, weight 6698496
# source 21, dest 21, weight 1847104
# source 21, dest 22, weight 2538592
# source 21, dest 23, weight 87808
# source 21, dest 24, weight 141120
# source 21, dest 25, weight 2220288
# source 22, dest 0, weight 10639720
# source 22, dest 1, weight 3806220
# source 22, dest 2, weight 5383060
# source 22, dest 3, weight 8102240
# source 22, dest 4, weight 27090680
# source 22, dest 5, weight 2335240
# source 22, dest 6, weight 4984900
# source 22, dest 7, weight 6833500
# source 22, dest 8, weight 15288080
# source 22, dest 9, weight 534040
# source 22, dest 10, weight 2442680
# source 22, dest 11, weight 6476420
# source 22, dest 12, weight 3611880
# source 22, dest 13, weight 11718860
# source 22, dest 14, weight 4988060
# source 22, dest 15, weight 1976580
# source 22, dest 16, weight 28440
# source 22, dest 17, weight 9944520
# source 22, dest 18, weight 9784940
# source 22, dest 19, weight 8407180
# source 22, dest 20, weight 6749760
# source 22, dest 21, weight 1861240
# source 22, dest 22, weight 2558020
# source 22, dest 23, weight 88480
# source 22, dest 24, weight 142200
# source 22, dest 25, weight 2237280
# source 23, dest 0, weight 10639720
# source 23, dest 1, weight 3806220
# source 23, dest 2, weight 5383060
# source 23, dest 3, weight 8102240
# source 23, dest 4, weight 27090680
# source 23, dest 5, weight 2335240
# source 23, dest 6, weight 4984900
# source 23, dest 7, weight 6833500
# source 23, dest 8, weight 15288080
# source 23, dest 9, weight 534040
# source 23, dest 10, weight 2442680
# source 23, dest 11, weight 6476420
# source 23, dest 12, weight 3611880
# source 23, dest 13, weight 11718860
# source 23, dest 14, weight 4988060
# source 23, dest 15, weight 1976580
# source 23, dest 16, weight 28440
# source 23, dest 17, weight 9944520
# source 23, dest 18, weight 9784940
# source 23, dest 19, weight 8407180
# source 23, dest 20, weight 6749760
# source 23, dest 21, weight 1861240
# source 23, dest 22, weight 2558020
# source 23, dest 23, weight 88480
# source 23, dest 24, weight 142200
# source 23, dest 25, weight 2237280
# source 24, dest 0, weight 10235680
# source 24, dest 1, weight 3661680
# source 24, dest 2, weight 5178640
# source 24, dest 3, weight 7794560
# source 24, dest 4, weight 26061920
# source 24, dest 5, weight 2246560
# source 24, dest 6, weight 4795600
# source 24, dest 7, weight 6574000
# source 24, dest 8, weight 14707520
# source 24, dest 9, weight 513760
# source 24, dest 10, weight 2349920
# source 24, dest 11, weight 6230480
# source 24, dest 12, weight 3474720
# source 24, dest 13, weight 11273840
# source 24, dest 14, weight 4798640
# source 24, dest 15, weight 1901520
# source 24, dest 16, weight 27360
# source 24, dest 17, weight 9566880
# source 24, dest 18, weight 9413360
# source 24, dest 19, weight 8087920
# source 24, dest 20, weight 6493440
# source 24, dest 21, weight 1790560
# source 24, dest 22, weight 2460880
# source 24, dest 23, weight 85120
# source 24, dest 24, weight 136800
# source 24, dest 25, weight 2152320
# source 25, dest 0, weight 10235680
# source 25, dest 1, weight 3661680
# source 25, dest 2, weight 5178640
# source 25, dest 3, weight 7794560
# source 25, dest 4, weight 26061920
# source 25, dest 5, weight 2246560
# source 25, dest 6, weight 4795600
# source 25, dest 7, weight 6574000
# source 25, dest 8, weight 14707520
# source 25, dest 9, weight 513760
# source 25, dest 10, weight 2349920
# source 25, dest 11, weight 6230480
# source 25, dest 12, weight 3474720
# source 25, dest 13, weight 11273840
# source 25, dest 14, weight 4798640
# source 25, dest 15, weight 1901520
# source 25, dest 16, weight 27360
# source 25, dest 17, weight 9566880
# source 25, dest 18, weight 9413360
# source 25, dest 19, weight 8087920
# source 25, dest 20, weight 6493440
# source 25, dest 21, weight 1790560
# source 25, dest 22, weight 2460880
# source 25, dest 23, weight 85120
# source 25, dest 24, weight 136800
# source 25, dest 25, weight 2152320

# %%
args_AS = {
    'pheromone_preference': 10,
    'heuristic_preference': 5,
    'Qval': 1,
    'evaporation': 0.5,
    'startpheromone': 2.0
}

args_ACO = {
    'pheromone_preference': 10,
    'heuristic_preference': 5,
    'Qval': 1,
    'evaporation': 0.5,
    'startpheromone': 2.0,
    'selectionTypeConst': 0.3,
    'ACS_qlearn_gamma': 0.5
}

args_MMAS = {
    'pheromone_preference': 10,
    'heuristic_preference': 6,
    'Qval': 1,
    'evaporation': 0.5,
    'startpheromone': 2.0,
    'best_pheromone_selection_prob': 0.05,
    'max_pheromone': 4.0,
    'min_pheromone': 0.5,
    'smoothing_coef': 0.5
}

args_ASRANK = {
    'pheromone_preference': 10,
    'heuristic_preference': 5,
    'Qval': 1,
    'evaporation': 0.5,
    'startpheromone': 1.0,
    'elite_multiplier': 25
}

# args_AS = {
#     'pheromone_preference': 1,
#     'heuristic_preference': 1,
#     'Qval': 1,
#     'evaporation': 0.5,
#     'startpheromone': 1.0
# }

# args_ACO = {
#     'pheromone_preference': 1,
#     'heuristic_preference': 1,
#     'Qval': 1,
#     'evaporation': 0.5,
#     'startpheromone': 1.0,
#     'selectionTypeConst': 0.5,
#     'ACS_qlearn_gamma': 0.5
# }

# args_MMAS = {
#     'pheromone_preference': 1,
#     'heuristic_preference': 1,
#     'Qval': 1,
#     'evaporation': 0.5,
#     'startpheromone': 1.0,
#     'best_pheromone_selection_prob': 0.05,
#     'max_pheromone': 2.0,
#     'min_pheromone': 0.5,
#     'smoothing_coef': 0.5
# }

# args_ASRANK = {
#     'pheromone_preference': 1,
#     'heuristic_preference': 1,
#     'Qval': 1,
#     'evaporation': 0.5,
#     'startpheromone': 1.0,
#     'elite_multiplier': 62
# }
# kro124p - 36230
# ft53 - 6905
# ft70 - 1950
# ftv35 - 1473

# %%
for d in range(0,5):
    G, solution = AntSystemTSP(graph,26,1000,stats_file,args_AS)
    besttour = solution.getTour()
    print(besttour)
    print(solution.getTourLength())
# Out:
# [1]
# 100000000.0
# [1]
# 100000000.0
# [1]
# 100000000.0
# [1]
# 100000000.0
# [1]
# 100000000.0

# %%
for d in range(0,5):
    graph, solution = ACO_TSP(graph,53,1000,stats_file,args_ACO)
    besttour = solution.getTour()
    print(besttour)
    print(solution.getTourLength())
# Out:
# [1, 8, 9, 6, 5, 51, 48, 49, 52, 50, 29, 28, 25, 27, 26, 3, 0, 36, 35, 40, 37, 18, 17, 16, 15, 39, 38, 45, 41, 43, 46, 44, 34, 32, 31, 33, 30, 13, 12, 14, 20, 21, 22, 42, 47, 7, 24, 23, 11, 10, 2, 4, 19, 1]
# 8684.0
# [1, 8, 6, 5, 51, 48, 49, 52, 50, 33, 31, 26, 25, 27, 29, 28, 3, 0, 36, 35, 38, 45, 41, 47, 42, 43, 46, 44, 34, 32, 30, 11, 10, 14, 12, 13, 17, 16, 15, 40, 37, 18, 19, 9, 7, 21, 20, 39, 4, 2, 23, 22, 24, 1]
# 8604.0
# [1, 8, 6, 5, 51, 48, 49, 52, 50, 29, 26, 25, 27, 28, 7, 9, 3, 0, 36, 35, 40, 37, 18, 17, 16, 15, 39, 4, 2, 11, 10, 12, 14, 13, 34, 32, 31, 33, 30, 38, 45, 41, 42, 46, 43, 44, 47, 23, 20, 21, 24, 22, 19, 1]
# 8301.0
# [1, 8, 6, 5, 51, 48, 49, 50, 52, 33, 31, 26, 25, 27, 29, 28, 42, 41, 43, 45, 44, 34, 32, 30, 0, 36, 35, 40, 37, 18, 17, 16, 15, 9, 7, 21, 20, 39, 38, 4, 2, 3, 13, 11, 10, 14, 12, 24, 22, 47, 46, 23, 19, 1]
# 8629.0
# [1, 8, 6, 5, 51, 48, 49, 52, 50, 33, 31, 26, 25, 27, 29, 28, 47, 46, 43, 41, 44, 34, 32, 30, 0, 2, 3, 13, 12, 14, 11, 10, 4, 17, 16, 15, 37, 35, 21, 20, 39, 38, 36, 40, 45, 42, 7, 9, 23, 22, 19, 18, 24, 1]
# 8708.0

# %%
for d in range(0,5):
    graph, solution = MMAS_TSP(graph,53,1000,stats_file,args_MMAS)
    besttour = solution.getTour()
    print(besttour)
    print(solution.getTourLength())
# Out:
# [1, 8, 9, 6, 5, 51, 48, 49, 52, 50, 33, 31, 30, 0, 41, 42, 46, 43, 45, 44, 34, 32, 26, 25, 27, 29, 28, 24, 22, 20, 21, 47, 7, 36, 35, 40, 37, 18, 17, 16, 15, 19, 11, 10, 12, 14, 13, 3, 2, 23, 39, 38, 4, 1]
# 8527.0
# [1, 6, 5, 51, 48, 49, 52, 50, 26, 25, 27, 29, 28, 11, 10, 41, 43, 42, 46, 45, 44, 34, 32, 31, 33, 30, 0, 3, 2, 17, 16, 15, 37, 35, 40, 36, 21, 20, 39, 38, 4, 22, 19, 18, 8, 9, 7, 12, 14, 13, 23, 24, 47, 1]
# 8560.0
# [1, 8, 6, 5, 51, 48, 49, 52, 50, 28, 25, 26, 27, 29, 34, 32, 33, 31, 30, 0, 36, 35, 37, 40, 38, 45, 41, 42, 46, 43, 47, 44, 23, 20, 11, 3, 2, 17, 16, 15, 18, 19, 7, 9, 13, 12, 14, 10, 39, 21, 24, 22, 4, 1]
# 8745.0
# [1, 8, 5, 51, 48, 49, 52, 50, 29, 28, 25, 27, 26, 41, 42, 46, 43, 45, 47, 44, 34, 32, 31, 33, 30, 0, 3, 2, 17, 16, 15, 37, 35, 40, 36, 10, 12, 14, 13, 11, 6, 9, 7, 21, 20, 39, 38, 4, 22, 19, 18, 23, 24, 1]
# 8279.0
# [1, 8, 6, 5, 51, 48, 49, 52, 50, 29, 28, 25, 27, 26, 34, 32, 31, 33, 30, 0, 3, 2, 15, 35, 40, 37, 21, 20, 39, 36, 38, 45, 41, 43, 42, 46, 44, 47, 7, 9, 10, 11, 13, 12, 14, 17, 16, 23, 24, 22, 19, 18, 4, 1]
# 8321.0

# %%
for d in range(0,5):
    graph, solution = ASRANK_TSP(graph,53,1000,stats_file,args_ASRANK)
    besttour = solution.getTour()
    print(besttour)
    print(solution.getTourLength())
# Out:
# [1, 8, 6, 5, 51, 48, 49, 52, 50, 33, 31, 30, 3, 0, 2, 15, 37, 35, 40, 38, 36, 32, 26, 25, 27, 29, 28, 10, 44, 41, 43, 42, 46, 45, 47, 34, 12, 14, 13, 11, 17, 16, 23, 20, 39, 4, 9, 7, 21, 24, 22, 19, 18, 1]
# 9105.0
# [1, 8, 6, 5, 49, 48, 52, 50, 51, 45, 41, 43, 42, 46, 44, 34, 32, 26, 25, 27, 29, 28, 33, 31, 30, 0, 36, 35, 40, 37, 38, 10, 14, 20, 21, 9, 7, 2, 16, 15, 19, 18, 17, 11, 3, 13, 12, 24, 22, 47, 23, 39, 4, 1]
# 8989.0
# [1, 0, 3, 2, 17, 16, 15, 52, 48, 49, 51, 50, 33, 31, 26, 25, 27, 29, 28, 7, 5, 9, 8, 6, 43, 41, 47, 44, 46, 45, 42, 34, 32, 30, 36, 35, 38, 37, 39, 40, 21, 20, 11, 12, 14, 13, 10, 4, 22, 19, 18, 23, 24, 1]
# 8949.0
# [1, 8, 6, 5, 51, 48, 49, 50, 52, 33, 31, 26, 25, 27, 29, 28, 20, 21, 38, 36, 35, 37, 18, 17, 16, 15, 7, 9, 3, 0, 11, 10, 12, 14, 13, 34, 32, 30, 2, 41, 42, 43, 45, 44, 46, 47, 24, 22, 19, 23, 39, 40, 4, 1]
# 9101.0
# [1, 8, 6, 5, 51, 48, 49, 52, 50, 32, 31, 33, 26, 25, 27, 29, 28, 21, 20, 11, 10, 12, 14, 13, 17, 15, 37, 35, 38, 36, 40, 39, 45, 41, 47, 42, 46, 43, 44, 34, 30, 9, 7, 3, 0, 2, 4, 22, 19, 18, 16, 23, 24, 1]
# 8863.0
